# %% [markdown]
# <a href="https://colab.research.google.com/github/deltorobarba/sciences/blob/master/chemistry_spectral_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Spectral Analysis of Elements**

# %%
# Call custom functions for spectral analysis
# !wget https://raw.githubusercontent.com/deltorobarba/astrophysics/main/chemistry_spectrum_oxygen.py
from chemistry_spectrum_oxygen import get_oxygen_nist_lines, wavelength_to_rgb, plot_nist_spectrum, wavelength_to_rgb, create_spectral_background, plot_oxygen_absorption

# %%
if __name__ == "__main__":
    plot_nist_spectrum(),
    plot_oxygen_absorption()
# Out:
# Oxygen spectral lines (NIST data):
# λ = 436.8 nm, Relative Intensity = 0.80
# λ = 441.5 nm, Relative Intensity = 0.75
# λ = 533.0 nm, Relative Intensity = 0.90
# λ = 543.5 nm, Relative Intensity = 0.85
# λ = 557.7 nm, Relative Intensity = 0.70
# λ = 577.0 nm, Relative Intensity = 0.65
# λ = 595.8 nm, Relative Intensity = 0.60
# λ = 615.7 nm, Relative Intensity = 0.55
# λ = 645.4 nm, Relative Intensity = 0.50
# λ = 677.3 nm, Relative Intensity = 0.45
# Oxygen absorption lines (NIST data):
# λ = 436.8 nm
# λ = 441.5 nm
# λ = 533.0 nm
# λ = 543.5 nm
# λ = 557.7 nm
# λ = 577.0 nm
# λ = 595.8 nm
# λ = 615.7 nm
# λ = 645.4 nm
# λ = 677.3 nm

# %%
# Call custom functions for spectral analysis
# !wget https://raw.githubusercontent.com/deltorobarba/astrophysics/main/chemistry_spectral_tools.py
from spectral_tools import get_atomic_levels, spectral_analysis, format_energy_levels

# %%
# For Oxygen
atom_name = 'O'
energy_levels = get_atomic_levels(atom_name)
spectral_analysis(atom_name, energy_levels)
format_energy_levels(energy_levels)
# Out:
# Electronic transitions for O:
# 3p → 2p: 115.52 nm
# 3s → 2p: 130.46 nm
# 3p → 3s: 1008.71 nm
#
# Energy levels:
# '2p': 0.00,  # Ground state
# '3s': 9.51,  # Excited state
# '3p': 10.74,  # Excited state

# %%
# For Calcium
atom_name = 'Ca'
energy_levels = get_atomic_levels(atom_name)
spectral_analysis(atom_name, energy_levels)
format_energy_levels(energy_levels)
# Out:
# Electronic transitions for Ca:
# 4p → 4s: 423.45 nm
# 3d → 4s: 659.95 nm
# 3d → 4p: 1181.63 nm
#
# Energy levels:
# '4s': 0.00,  # Ground state
# '3d': 1.88,  # Excited state
# '4p': 2.93,  # Excited state

# %%
# For Carbon
atom_name = 'C'
energy_levels = get_atomic_levels(atom_name)
spectral_analysis(atom_name, energy_levels)
format_energy_levels(energy_levels)
# Out:
# Electronic transitions for C:
# 3p → 2p: 143.60 nm
# 3s → 2p: 165.87 nm
# 3p → 3s: 1069.58 nm
#
# Energy levels:
# '2p': 0.00,  # Ground state
# '3s': 7.48,  # Excited state
# '3p': 8.64,  # Excited state

# %%
# For Helium
atom_name = 'He'
energy_levels = get_atomic_levels(atom_name)
spectral_analysis(atom_name, energy_levels)
format_energy_levels(energy_levels)
# Out:
# Electronic transitions for He:
# 2p → 1s: 58.47 nm
# 2s → 1s: 60.17 nm
# 2p → 2s: 2067.85 nm
#
# Energy levels:
# '1s': 0.00,  # Ground state
# '2s': 20.62,  # Excited state
# '2p': 21.22,  # Excited state

# %%
# Argon
atom_name = 'Ar'
energy_levels = get_atomic_levels(atom_name)
spectral_analysis(atom_name, energy_levels)
format_energy_levels(energy_levels)
# Out:
# Electronic transitions for Ar:
# 3d → 3p: 92.04 nm
# 4s → 3p: 105.86 nm
# 3d → 4s: 704.95 nm
#
# Energy levels:
# '3p': 0.00,  # Ground state
# '4s': 11.72,  # Excited state
# '3d': 13.48,  # Excited state

# %%
# Example usage for Calcium
if __name__ == "__main__":
    atom_name = 'Ca'
    energy_levels = get_atomic_levels(atom_name)
    spectral_analysis(atom_name, energy_levels)
    format_energy_levels(energy_levels)
