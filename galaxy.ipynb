# %% [markdown]
# <a href="https://colab.research.google.com/github/deltorobarba/sciences/blob/master/galaxy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Galaxy and Nebula Research 🔭⋆₊ 🫧⋆**

# %%
# !pip install astropy astroquery reproject lightkurve -q
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.io import fits
from astropy.nddata import Cutout2D
from astropy.wcs import WCS
from astropy import coordinates
import numpy as np
import matplotlib.pyplot as plt
from astroquery.ipac.irsa import Irsa
from astroquery.simbad import Simbad
from astroquery.ned import Ned
from astroquery.sdss import SDSS
from reproject import reproject_interp
from astropy.visualization import make_lupton_rgb
from astropy.visualization import astropy_mpl_style
from astroquery.mast import Observations
from astropy.visualization.mpl_normalize import ImageNormalize
from astropy.visualization import ZScaleInterval, ImageNormalize
from astropy.utils.data import get_pkg_data_filename
from astropy.visualization import astropy_mpl_style
# %matplotlib inline

# %%
########################################################################
# Define Object (Galaxy or Nebula) and Coordinates
########################################################################

#object_name = 'M 104'   # Sombrero Galaxy
object_name = 'M 51'     # Whirlpool Galaxy
#object_name = 'M 27'    # Orion Nebula
#object_name = 'M 42'    # Dumbbell Nebula

# %%
# Get skycoordinates of desired object
galaxy = Simbad.query_object(object_name)
ra_hms = galaxy['ra'][0]
dec_dms = galaxy['dec'][0]
print(galaxy)
print("\n")
print("-"*60)
print("RA (h:m:s):", ra_hms)
print("DEC (d:m:s):", dec_dms)
# Out:
# main_id     ra            dec        ...     coo_bibcode     matched_id
#            deg            deg        ...
# ------- ---------- ----------------- ... ------------------- ----------
#   M  51 202.469575 47.19525833333333 ... 2006AJ....131.1163S      M  51
#
#
# ------------------------------------------------------------
# RA (h:m:s): 202.469575
# DEC (d:m:s): 47.19525833333333

# %%
# Set Coordinates: When Simbad data (RA and DEC columns) are in sexagesimal/hour-angle format:
# coord = SkyCoord(ra=ra_hms, dec=dec_dms, unit=('hourangle', 'deg'), frame='icrs')
# Set Coordinates: When Simbad data (RA and DEC columns) are in degrees (deg) format:
coord = SkyCoord(ra=ra_hms, dec=dec_dms, unit='deg', frame='icrs')

# %%
########################################################################
# IRSA data
########################################################################

# FITS infrared images. How many science picture are therein spitzer_images?
spitzer_images = Irsa.query_sia(pos=(coord, 1 * u.arcmin), collection='spitzer_seip')
science_images_count = len(spitzer_images[spitzer_images['dataproduct_subtype'] == 'science'])
print("Number of science images:", science_images_count)
# Out:
# Number of science images: 24

# %%
# Query IRSA database
spitzer_images = Irsa.query_sia(pos=(coord, 1 * u.arcmin), collection='spitzer_seip')

# %%
# Open a cutout image for one of the science images (Filter for science images only)
science_image = spitzer_images[spitzer_images['dataproduct_subtype'] == 'science'][4]  # --> set here image number
with fits.open(science_image['access_url'], use_fsspec=True) as hdul:
    cutout = Cutout2D(hdul[0].data, position=coord, size=2 * u.arcmin, wcs=WCS(hdul[0].header))

plt.figure(figsize=(10, 8))
plt.imshow(cutout.data, cmap='viridis')
plt.colorbar()
plt.title(f'Spitzer Image of {object_name} galaxy')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Open a cutout image for one of the science images (Filter for science images only)
science_image = spitzer_images[spitzer_images['dataproduct_subtype'] == 'science'][5]  # --> set here image number
with fits.open(science_image['access_url'], use_fsspec=True) as hdul:
    cutout = Cutout2D(hdul[0].data, position=coord, size=2 * u.arcmin, wcs=WCS(hdul[0].header))

plt.figure(figsize=(10, 8))
plt.imshow(cutout.data, cmap='plasma')
plt.colorbar()
plt.title(f'Spitzer Image of {object_name} galaxy')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
########################################################################
# SDSS data
########################################################################

# Check SDSS data availability for the region
sdss_table = SDSS.query_region(coord, radius=2*u.arcmin) # broaden radius to 2 arcmin to ensure the image field is captured
print(sdss_table)
# Out:
#        ra              dec               objid        run  rerun camcol field
# ---------------- ---------------- ------------------- ---- ----- ------ -----
# 202.423565762729 47.1979135351773 1237661362908561423 3699   301      6   100
# 202.423570475396 47.1979195927486 1237661362908561450 3699   301      6   100
# 202.430199123592 47.1938321739851 1237661362908561428 3699   301      6   100
# 202.429572347252 47.1937386454686 1237661362908561465 3699   301      6   100
# 202.429194297914 47.1936535205096 1237661362908561464 3699   301      6   100
# 202.430088629797 47.1966604307787 1237661362908561488 3699   301      6   100
# 202.443772166603 47.2092324418382 1237661362908561462 3699   301      6   100
# 202.449162752924 47.2099780507497 1237661362908561438 3699   301      6   100
# 202.435548751036 47.2091725013563 1237661362908561453 3699   301      6   100
# 202.449001926547 47.2045267845868 1237661362908561503 3699   301      6   100
#              ...              ...                 ...  ...   ...    ...   ...
#  202.45801226814 47.1956465058027 1237661362908561466 3699   301      6   100
# 202.457931499645 47.1956654944754 1237661362908561429 3699   301      6   100
#  202.46070077128 47.2124254009397 1237661362908561478 3699   301      6   100
# 202.460860923008 47.2123789188673 1237661362908561437 3699   301      6   100
# 202.441755976299 47.1799748684403 1237661362908561448 3699   301      6   100
# 202.441759712355 47.1799738120971 1237661362908561447 3699   301      6   100
# 202.441757443327 47.1799740591076 1237661362908561434 3699   301      6   100
# 202.461073278613  47.227999712693 1237661362908561494 3699   301      6   100
# 202.480590655247 47.1680197298315 1237661362908561456 3699   301      6   100
# 202.480544159544 47.1679843989206 1237661362908561426 3699   301      6   100
# Length = 47 rows

# %%
plt.style.use(astropy_mpl_style)
# Define the SDSS parameters from the result table (example)
run = 6073
rerun = 301
camcol = 4
field = 64

# Query the image using the specific SDSS parameters
try:
    # Adjust the filter band (e.g., 'r', 'g', 'i', 'z') to see how the object appears in different wavelengths
    images = SDSS.get_images(run=run, rerun=rerun, camcol=camcol, field=field, band='g')

    # Display the first image result
    for image in images:
        plt.figure(figsize=(10, 10)) # Main plot size
        plt.imshow(image[0].data, cmap='inferno') # Display the image data
        cbar = plt.colorbar(shrink=0.6) # Shrink to make colorbar vertically smaller
        cbar.ax.tick_params(labelsize=10) # Font size of colorbar ticks
        plt.title(f'SDSS Image (run: {run}, camcol: {camcol}, field: {field})', fontsize=14)
        plt.tick_params(axis='both', which='major', labelsize=10) # Axis labels and ticks
        plt.show()

except Exception as e:
    print(f"An error occurred: {e}")

# %%
###############################################
# Create for Multi-Wavelength Composite (with MAST)
###############################################

# Function to create composite image
def process_hst_images(params):
    # Search for observations
    obs_table = Observations.query_region(params.coords, radius=params.search_radius)

    # Filter for HST observations with specific filters
    hst_obs = obs_table[obs_table['instrument_name'] == params.instrument]

    # Get observations for each filter
    filter_data = {}
    for color, filter_name in params.rgb_filters.items():
        filter_data[color] = hst_obs[hst_obs['filters'] == filter_name]
        print(f"{filter_name}: {len(filter_data[color])} observations")

    # Check if we have all required filters
    if all(len(data) > 0 for data in filter_data.values()):

        # Download and process each filter
        hdus = {}
        for color, observations in filter_data.items():
            products = Observations.get_product_list(observations[0]['obsid'])
            files = Observations.download_products(products[products['productSubGroupDescription'] == 'DRZ'])
            hdus[color] = fits.open(files['Local Path'][0])[1]

        # Reproject images to match the red channel (Aligning images)
        aligned_data = {
            'red': hdus['red'].data,
            'green': reproject_interp(hdus['green'], hdus['red'].header)[0],
            'blue': reproject_interp(hdus['blue'], hdus['red'].header)[0]}

        # Normalize the data
        normalized_data = {color: normalize(data) for color, data in aligned_data.items()}

        # Create RGB image
        rgb = make_lupton_rgb(
            normalized_data['red'],
            normalized_data['green'],
            normalized_data['blue'],
            Q=params.rgb_params['Q'],
            stretch=params.rgb_params['stretch'])

        plt.figure(figsize=params.figure_size)
        plt.imshow(rgb, origin='lower')
        plt.title(f'{params.object_name} - HST {params.instrument} Composite')
        plt.axis('off')
        plt.show()
    else:
        print("Could not find all required filter observations")

def normalize(arr): # Normalize array data
    arr = np.nan_to_num(arr, 0)  # Replace NaN with 0
    return arr / np.percentile(arr[arr > 0], 99)

# Filter combinations for Object (HST observations)
# coords = coord # SkyCoord('13h29m52.7s +47d11m43s', unit=(u.hourangle, u.deg)) # e.g. for M51
obs_table = Observations.query_region(coord, radius=0.2 * u.deg) # Search for observations

# Get unique combinations of instruments and filters
hst_obs = obs_table[obs_table['obs_collection'] == 'HST']
unique_filters = {}

for obs in hst_obs:
    instrument = obs['instrument_name']
    filt = obs['filters']
    if instrument not in unique_filters:
        unique_filters[instrument] = set()
    if filt:  # Some observations might not have filter info
        unique_filters[instrument].add(filt)

# Print available filters by instrument
for instrument, filters in unique_filters.items():
    print(f"\n{instrument} filters:")
    for f in sorted(filters):
        print(f"  - {f}")

# %%
# Composite Image using ++ ACF/WFC instruments
class ObservationParams:
    def __init__(self):
        self.coords = coord  # Target coordinates earlier
        self.search_radius = 0.2 * u.deg
        self.rgb_filters = {'blue': 'F435W', 'green': 'F555W', 'red': 'F814W'}
        self.instrument = 'ACS/WFC'
        self.rgb_params = {'Q': 10, 'stretch': 0.5} # Image processing parameters
        self.figure_size = (10, 10) # Visualization parameters
        self.object_name = object_name

params = ObservationParams()
process_hst_images(params)
# Out:
# F435W: 107 observations
# F555W: 80 observations
# F814W: 171 observations
#
# Downloading data products...
# INFO:astroquery:Found cached file ./mastDownload/HST/j97c31rrq/j97c31rrq_drz.fits with expected size 214447680.
# INFO: Found cached file ./mastDownload/HST/j97c31rrq/j97c31rrq_drz.fits with expected size 214447680. [astroquery.query]
# INFO:astroquery:Found cached file ./mastDownload/HST/j97c31rsq/j97c31rsq_drz.fits with expected size 214395840.
# INFO: Found cached file ./mastDownload/HST/j97c31rsq/j97c31rsq_drz.fits with expected size 214395840. [astroquery.query]
# INFO:astroquery:Found cached file ./mastDownload/HST/j97c31ruq/j97c31ruq_drz.fits with expected size 214344000.
# INFO: Found cached file ./mastDownload/HST/j97c31ruq/j97c31ruq_drz.fits with expected size 214344000. [astroquery.query]
# Aligning images...
# Normalizing data...
# Creating color composite...

# %%
# Composite Image using ++ WFC3/UVIS instruments
class ObservationParams:
    def __init__(self):
        self.coords = coord # Target coordinates earlier
        self.search_radius = 0.2 * u.deg
        self.rgb_filters = {'blue': 'F275W', 'green': 'F606W', 'red': 'F814W'}
        self.instrument = 'WFC3/UVIS'
        self.rgb_params = {'Q': 10, 'stretch': 0.5} # Image processing parameters
        self.figure_size = (10, 10) # Visualization parameters
        self.object_name = object_name

params = ObservationParams()
process_hst_images(params)
# Out:
# F275W: 36 observations
# F606W: 77 observations
# F814W: 15 observations
#
# Downloading data products...
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/icd401010_drz.fits to ./mastDownload/HST/icd401010/icd401010_drz.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieya01010_drz.fits to ./mastDownload/HST/ieya01010/ieya01010_drz.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ieya01040_drz.fits to ./mastDownload/HST/ieya01040/ieya01040_drz.fits ... [Done]
# Aligning images...
# Normalizing data...
# Creating color composite...

# %%
########################################################################
# Analyse composite RGB FITS (with ZScaleInterval)
########################################################################

# Stretch and Scale RGB Layers (NGC 6975)
# Three images of Galaxy NGC 6975 (https://docs.astropy.org/en/latest/visualization/rgb.html)
# 1. Load the sample FITS data (g, r, i bands)
g_name = get_pkg_data_filename('visualization/reprojected_sdss_g.fits.bz2')
r_name = get_pkg_data_filename('visualization/reprojected_sdss_r.fits.bz2')
i_name = get_pkg_data_filename('visualization/reprojected_sdss_i.fits.bz2')
g = fits.getdata(g_name)
r = fits.getdata(r_name)
i = fits.getdata(i_name)
#print(g_header)

# 2. Create the two RGB composite images
  # Image 1: Default parameters (Q=8, stretch=1.0)
rgb_default = make_lupton_rgb(i, r, g)
  # Image 2: Custom Lupton stretch (Q=10, stretch=0.5)
rgb_custom = make_lupton_rgb(i, r, g, Q=10, stretch=0.5)

# 3. Set up the figure and two subplots side-by-side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# --- Plot 1: Default Lupton Stretch ---
# RGB data does not use a colorbar (it is color data, not scalar flux data)
ax1.imshow(rgb_default, origin='lower')
ax1.set_title('NGC 6975 RGB Composite (Default Parameters)', fontsize=12)
ax1.axis('off') # Hide axes ticks/labels for clean image display

# --- Plot 2: Custom Lupton Stretch (Q=10, stretch=0.5) - faint features of galaxies appear ---
# (Compare with Fig. 1 of Lupton (2004) or SDSS Skyserver image, https://docs.astropy.org/en/stable/utils/data.html)
ax2.imshow(rgb_custom, origin='lower')
ax2.set_title('NGC 6975 RGB Composite (Q=10, stretch=0.5)', fontsize=12)
ax2.axis('off') # Hide axes ticks/labels for clean image display

# Adjust spacing and display
plt.tight_layout()
plt.show()

# %%
# Green Band: Single Filter vs ZScaleInterval (NGC 6975)
norm = ImageNormalize(g, interval=ZScaleInterval())
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# --- Plot 1: Simple Basic Display (Linear/Default Scaling) ---
im1 = ax1.imshow(g, origin='lower', cmap='gray')
cbar1 = fig.colorbar(im1, ax=ax1, shrink=0.6)
ax1.set_title('g-band image (Simple Basic Display)', fontsize=10)

# --- Plot 2: ZScale Normalized Display ---
im2 = ax2.imshow(g, origin='lower', cmap='viridis', norm=norm)
cbar2 = fig.colorbar(im2, ax=ax2, shrink=0.6)
ax2.set_title('g-band image (with ZScale Normalization)', fontsize=10)

plt.tight_layout()
plt.show()

# %%
# Ultraviolet: Single Filter vs ZScaleInterval (NGC 6975)
# !wget https://raw.githubusercontent.com/deltorobarba/repo/main/file-u-001737-5-0039.fits
# !wget https://raw.githubusercontent.com/deltorobarba/repo/main/file-z-001737-5-0039.fits

"""
Loading galaxy data from:
* https://skyserver.sdss.org/dr18/VisualTools/explore/summary?name=NGC%206975&ra=313.1084419845900&dec=-05.7723173124500
* https://skyserver.sdss.org/dr18/VisualTools/explore/fitsimg?id=1237652935641858730&spec=&apid=&fieldId=0x112d06c9a0270000&ra=313.108952897284&dec=-5.77174594873709&plateId=&mangaid=

Available data:
* u: Ultraviolet band (centered at approximately 354 nm) --> data that we are loading
* g: Green band (centered at approximately 477 nm)
* r: Red band (centered at approximately 623 nm)
* i: Near-infrared band (centered at approximately 762 nm)
* z: Another infrared band, further in wavelength than i (centered at approximately 913 nm)
"""

# Specify the path to the FITS file
#fits_file = './file-u-001737-5-0039.fits'
fits_file = './file-z-001737-5-0039.fits'

# Use a context manager (recommended practice)
with fits.open(fits_file) as hdul:
    # Extract the image data from the primary HDU (header data unit)
    image_data = hdul[0].data

    # 2. Create the normalization object using the FITS data
    norm = ImageNormalize(image_data, interval=ZScaleInterval())

    # Set up the figure and two subplots side-by-side
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

    # --- Plot 1: Simple Basic Display (Linear/Default Scaling) ---
    # Use the loaded image_data
    im1 = ax1.imshow(image_data, origin='lower', cmap='gray', aspect='equal')
    cbar1 = fig.colorbar(im1, ax=ax1, shrink=0.6)
    ax1.set_title('z-band image (Simple Basic Display)', fontsize=10)

    # --- Plot 2: ZScale Normalized Display ---
    # Use the loaded image_data and the calculated 'norm'
    im2 = ax2.imshow(image_data, origin='lower', cmap='viridis', norm=norm, aspect='equal')
    cbar2 = fig.colorbar(im2, ax=ax2, shrink=0.6)
    ax2.set_title('z-band image (with ZScale Normalization)', fontsize=10)

    # Adjust spacing and display
    plt.tight_layout()
    plt.show()
# Out:
# --2025-12-16 17:41:41--  https://raw.githubusercontent.com/deltorobarba/repo/main/file-u-001737-5-0039.fits
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12447360 (12M) [application/octet-stream]
# Saving to: ‘file-u-001737-5-0039.fits.6’
#
# file-u-001737-5-003 100%[===================>]  11.87M  --.-KB/s    in 0.08s
#
# 2025-12-16 17:41:41 (146 MB/s) - ‘file-u-001737-5-0039.fits.6’ saved [12447360/12447360]
#
# --2025-12-16 17:41:41--  https://raw.githubusercontent.com/deltorobarba/repo/main/file-z-001737-5-0039.fits
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12447360 (12M) [application/octet-stream]
# Saving to: ‘file-z-001737-5-0039.fits.6’
#
# file-z-001737-5-003 100%[===================>]  11.87M  --.-KB/s    in 0.07s
#
# 2025-12-16 17:41:41 (165 MB/s) - ‘file-z-001737-5-0039.fits.6’ saved [12447360/12447360]

# %%
########################################################################
# Get more details from FITS file
########################################################################
hdul = fits.open(science_image['access_url'], use_fsspec=True)
hdul.info()
#  Access the primary HDU (Header/Data Unit) to get the data
primary_hdu = hdul[0]
data = primary_hdu.data
print(primary_hdu.header) # Display the header to learn more about the file
print(repr(hdul[0].header))  # Science data HDU header
# Out:
# Filename: <class 'fsspec.implementations.http.HTTPFile'>
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      77   (4597, 6573)   float32
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel - floating point                NAXIS   =                    2 / Number of axes                                 NAXIS1  =                 4597 / X axis length                                  NAXIS2  =                 6573 / Y axis length                                  ORIGIN  = 'Spitzer Super-Mosaic Pipeline' / Origin of these image data          CREATOR = 'Spitzer Science Center' / Creator of this FITS file                                                                                                            / TIME AND EXPOSURE INFORMATION                                                                                                                       TELESCOP= 'Spitzer '           / Name of Telescope                              INSTRUME= 'IRAC    '           / Name of Instrument                             CHNLNUM =                    2 / Instrument channel number                      WAVELEN =                  4.5 / Effective wavelength of band in microns        MJDSTART=         53143.354842 / MJD of first observation in mosaic             MJDMEAN =         53363.287951 / Mean MJD of observations in mosaic             MJDMED  =            53147.824 / Median MJD of observations in mosaic           MJDEND  =         54097.995437 / MJD of last observation in mosaic              EXPTIME =                 7.04 / Mean exposure time in seconds per pixel        MEXPTIME=                   7. / Median exposure time in seconds per pixel      ETMIN   =                   1. / Minimum exposure time in seconds of input exposETMAX   =                   1. / Maximum exposure time in seconds of input exposCOV     =                 7.04 / Mean coverage in exposures per pixel           MEDCOV  =                 7.04 / Median coverage in exposures per pixel         SATMAX  =             2073.000 / Soft saturation counts for shortest exposure inSATMIN  =             2073.000 / Soft saturation counts for longest exposure / S                                                                                          / SUPER-MOSAIC DATA PRODUCT INFORMATION                                                                                                               IMTYPE  = 'mean    '           / Image product type                             REGID   =             50069620 / Mosaic region identifier                       SUBREGID= '50069620-0-short'   / Sub-mosaic region identifier                   NXTILE  =                    1 / Number of sub-region tiles in X direction      NYTILE  =                    1 / Number of sub-region tiles in Y direction      XTILE   =                    0 / X position of sub-region tile                  YTILE   =                    0 / Y position of sub-region tile                  SMCASE  =                    4 / Super-Mosaic use-case                                                                                                                    / DATA PROCESSING INFORMATION                                                                                                                         OVRLPNL = 'overlap_gal_irac.nl' / Overlap correction namelist                   MOSNL   = 'mosaic_gal_shallow_irac.nl' / Mosaic namelist                        MOPEXVER= '18.5.4  '           / Version of MOPEX used for mosaic processing    PIPEVER = 'S18.25.0'           / Version of calibration pipeline for input imageSMVER   = '2.0     '           / Super-Mosaic pipeline version                  FCREATE = '2012-10-01T21:10:48' / File creation date/time (UTC)                                                                                                           / PHOTOMETRY                                                                                                                                          BUNIT   = 'MJy/sr  '           / Units for image counts                          ...
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel - floating point
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                 4597 / X axis length
# NAXIS2  =                 6573 / Y axis length
# ORIGIN  = 'Spitzer Super-Mosaic Pipeline' / Origin of these image data
# CREATOR = 'Spitzer Science Center' / Creator of this FITS file
#
#           / TIME AND EXPOSURE INFORMATION
#
# TELESCOP= 'Spitzer '           / Name of Telescope
# INSTRUME= 'IRAC    '           / Name of Instrument
# CHNLNUM =                    2 / Instrument channel number
# WAVELEN =                  4.5 / Effective wavelength of band in microns
# MJDSTART=         53143.354842 / MJD of first observation in mosaic
# MJDMEAN =         53363.287951 / Mean MJD of observations in mosaic
# MJDMED  =            53147.824 / Median MJD of observations in mosaic
# MJDEND  =         54097.995437 / MJD of last observation in mosaic
# EXPTIME =                 7.04 / Mean exposure time in seconds per pixel
# MEXPTIME=                   7. / Median exposure time in seconds per pixel
# ETMIN   =                   1. / Minimum exposure time in seconds of input expos
# ETMAX   =                   1. / Maximum exposure time in seconds of input expos
# COV     =                 7.04 / Mean coverage in exposures per pixel
# MEDCOV  =                 7.04 / Median coverage in exposures per pixel
# SATMAX  =             2073.000 / Soft saturation counts for shortest exposure in
# SATMIN  =             2073.000 / Soft saturation counts for longest exposure / S
#
#           / SUPER-MOSAIC DATA PRODUCT INFORMATION
#
# IMTYPE  = 'mean    '           / Image product type
# REGID   =             50069620 / Mosaic region identifier
# SUBREGID= '50069620-0-short'   / Sub-mosaic region identifier
# NXTILE  =                    1 / Number of sub-region tiles in X direction
# NYTILE  =                    1 / Number of sub-region tiles in Y direction
# XTILE   =                    0 / X position of sub-region tile
# YTILE   =                    0 / Y position of sub-region tile
# SMCASE  =                    4 / Super-Mosaic use-case
#
#           / DATA PROCESSING INFORMATION
#
# OVRLPNL = 'overlap_gal_irac.nl' / Overlap correction namelist
# MOSNL   = 'mosaic_gal_shallow_irac.nl' / Mosaic namelist
# MOPEXVER= '18.5.4  '           / Version of MOPEX used for mosaic processing
# PIPEVER = 'S18.25.0'           / Version of calibration pipeline for input image
# SMVER   = '2.0     '           / Super-Mosaic pipeline version
# FCREATE = '2012-10-01T21:10:48' / File creation date/time (UTC)
#
#           / PHOTOMETRY
#
# BUNIT   = 'MJy/sr  '           / Units for image counts
# GAIN    =              189.098 / Mean conversion in e- / Mean conversion in e-/(
# EXPGAIN =                3.710 / e- / e-/DN for input exposures
# EFCONV  =               0.1382 / (MJy / (MJy/sr)/(DN/s) for input exposures
# ZPAB    =              21.5814 / Magnitude Zero-Point on AB System
# ZPVEGA  =              18.3174 / Magnitude Zero-Point on Vega System
#
#           / ASTROMETRY
#
# RADESYS = 'ICRS    '           / International Celestial Reference System
# CRVAL1  =           202.406597 / [deg] RA of reference point
# CRVAL2  =            46.961402 / [deg] DEC of reference point
# CRPIX1  =             2299.226 / [pix] Image reference point
# CRPIX2  =             3287.087 / [pix] Image reference point
# CTYPE1  = 'RA---TAN'           / RA projection type
# CTYPE2  = 'DEC--TAN'           / DEC projection type
# PA      =                  -0. / [deg] Position angle of axis 2 (E of N)
# CD1_1   =          -0.00016667 / Transformation matrix
# CD1_2   =                  -0.
# CD2_1   =                  -0.
# CD2_2   =           0.00016667
# PIXSCALE=                  0.6 / arcsec/pix
# EQUINOX =                2000. / [yr] Equatorial coordinates definition
#
#           / SKY BACKGROUND INFORMATION
#
# ISM_EST =                0.005 / Estimated mean ISM background MJy/str
# ZODY_EST=                0.231 / Estimated mean Zody background MJy/str
