# %% [markdown]
# <a href="https://colab.research.google.com/github/deltorobarba/sciences/blob/master/cosmology_distance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Cosmology Distance**

# %%
# !pip install hmf -q
from hmf import cosmo
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# https://hmf.readthedocs.io/en/latest/examples/deal_with_cosmology.html

# %%
my_cosmo = cosmo.Cosmology()

# %%
print("Matter density: ", my_cosmo.cosmo.Om0)
print("Hubble constant: ", my_cosmo.cosmo.H0)
print("Dark Energy density: ", my_cosmo.cosmo.Ode0)
print("Baryon density: ",  my_cosmo.cosmo.Ob0)
print("Curvature density: ", my_cosmo.cosmo.Ok0)
# Out:
# Matter density:  0.277
# Hubble constant:  70.2 km / (Mpc s)
# Dark Energy density:  0.7229152347340179
# Baryon density:  0.0459
# Curvature density:  0.0

# %%
z = np.linspace(0,8,100)
plt.plot(z,my_cosmo.cosmo.comoving_distance(z))
plt.ylabel("Comoving Distance, [Mpc]")
plt.xlabel("Redshift")
# Out:
# Text(0.5, 0, 'Redshift')

# %%
my_cosmo = cosmo.Cosmology(cosmo_model=cosmo.WMAP5)
print("WMAP5 baryon density: ", my_cosmo.cosmo.Ob0)
# Out:
# WMAP5 baryon density:  0.0459

# %%
for Om0 in np.linspace(0.2,0.4,7):
    my_cosmo.update(cosmo_params={"Om0":Om0})
    plt.plot(z,my_cosmo.cosmo.comoving_distance(z),label="%s"%Om0)
_ = plt.legend(loc=0)

# %% [markdown]
# https://docs.astropy.org/en/stable/cosmology/index.html

# %%
# !pip install astropy -q
from astropy.cosmology import WMAP9 as cosmo

# %%
cosmo.H(0)
# Out:
# <Quantity 69.32 km / (Mpc s)>

# %%
import numpy as np
from astropy.cosmology import WMAP9 as cosmo
cosmo.comoving_distance(np.array([0.5, 1.0, 1.5]))
# Out:
# <Quantity [1916.06941724, 3363.07062107, 4451.7475201 ] Mpc>

# %%
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=70, Om0=0.3, Tcmb0=2.725)
print(cosmo)
# Out:
# FlatLambdaCDM(H0=70.0 km / (Mpc s), Om0=0.3, Tcmb0=2.725 K, Neff=3.04, m_nu=[0. 0. 0.] eV, Ob0=None)

# %%
import astropy.units as u
from astropy.cosmology import Planck13, z_at_value
z_at_value(Planck13.age, 2 * u.Gyr)
# Out:
# <Quantity 3.19812061 redshift>
