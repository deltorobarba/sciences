# %% [markdown]
# <a href="https://colab.research.google.com/github/deltorobarba/sciences/blob/master/nebula_NGC_602.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Nebula NGC 602**

# %% [markdown]
# [NGC 602](https://de.m.wikipedia.org/wiki/NGC_602) is a nebula, specifically an emission nebula located in the Small Magellanic Cloud, a satellite galaxy of the Milky Way. It’s part of an active star-forming region, with young, hot stars illuminating and shaping the surrounding gas and dust, creating a stunning view. NGC 602 is often studied to understand stellar formation processes in low-metallicity environments, similar to those of early galaxies.

# %% [markdown]
# ![sciences](https://upload.wikimedia.org/wikipedia/commons/thumb/8/8d/NGC_602_%28Hubble_image%29_%28weic2425b%29.jpg/1268px-NGC_602_%28Hubble_image%29_%28weic2425b%29.jpg)

# %% [markdown]
# NGC 602 is an **open star cluster** located within a bright emission nebula in the **Small Magellanic Cloud (SMC)**, a satellite galaxy of the Milky Way. It is often associated with its surrounding nebula, sometimes referred to as the "Wing" of the SMC.
#
# The bright nebula surrounding NGC 602 is rich in young, hot stars that have formed from the surrounding gas and dust. These stars illuminate the nebula, making it a prominent region of star formation. This combination of the open cluster and its emission nebula is what makes NGC 602 a fascinating object of study in the context of stellar and nebular evolution.

# %% [markdown]
# https://de.m.wikipedia.org/wiki/NGC_602
#
# Near the outskirts of the Small Magellanic Cloud, a satellite galaxy roughly 200 000 light-years from Earth, lies the young star cluster NGC 602.
# Brown dwarfs are the more massive cousins of giant gas planets (typically ranging from roughly 13 to 75 Jupiter masses, and sometimes lower).
# They are free-floating, meaning that they are not gravitationally bound to a star as exoplanets are.
# However, some of them share characteristics with exoplanets, like their atmospheric composition and storm patterns.
# This discovery highlights the power of using both Hubble and Webb to study young stellar clusters.
# Hubble showed that NGC602 harbors very young low mass stars, but only with Webo we can finally see the extent and the significance of the substellar mass formation in this cluster.

# %%
# !pip install astropy astroquery -q
from astroquery.ipac.irsa import Irsa
from astropy import units as u
from astropy.coordinates import SkyCoord
from astroquery.simbad import Simbad
from astropy import coordinates
from astropy.io import fits
from astropy.nddata import Cutout2D
from astropy.wcs import WCS
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# *Load data with FITS via IRSA*

# %%
# Get skycoordinates of desired object
galaxy = Simbad.query_object('ngc602')
ra_hms = galaxy['RA'][0]
dec_dms = galaxy['DEC'][0]
print(galaxy)
# Out:
#  MAIN_ID       RA          DEC      RA_PREC ... COO_WAVELENGTH     COO_BIBCODE     SCRIPT_NUMBER_ID
#             "h:m:s"      "d:m:s"            ...
# --------- ------------ ------------ ------- ... -------------- ------------------- ----------------
# NGC   602 01 29 32.133 -73 33 38.13       7 ...              O 2012ApJ...748...64G                1

# %%
print("RA (h:m:s):", ra_hms)
print("DEC (d:m:s):", dec_dms)
# Out:
# RA (h:m:s): 01 29 32.133
# DEC (d:m:s): -73 33 38.13

# %%
# Simple image access queries from IRSA images from Spitzer telescope
coord = SkyCoord(ra=ra_hms, dec=dec_dms, unit=('hourangle', 'deg'), frame='icrs')
spitzer_images = Irsa.query_sia(pos=(coord, 1 * u.arcmin), collection='spitzer_seip').to_table()

# Open a cutout image for one of the science images
science_image = spitzer_images[spitzer_images['dataproduct_subtype'] == 'science'][0]
with fits.open(science_image['access_url'], use_fsspec=True) as hdul:
    cutout = Cutout2D(hdul[0].section, position=coord, size=2 * u.arcmin, wcs=WCS(hdul[0].header))

plt.figure(figsize=(10, 8))
plt.imshow(cutout.data, cmap='inferno')
plt.colorbar()
plt.title('Spitzer Image of Nebula NGC 602')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Simple image access queries from IRSA images from Spitzer telescope
coord = SkyCoord(ra=ra_hms, dec=dec_dms, unit=('hourangle', 'deg'), frame='icrs')
spitzer_images = Irsa.query_sia(pos=(coord, 1 * u.arcmin), collection='spitzer_seip').to_table()

# Open a cutout image for one of the science images
science_image = spitzer_images[spitzer_images['dataproduct_subtype'] == 'science'][1]
with fits.open(science_image['access_url'], use_fsspec=True) as hdul:
    cutout = Cutout2D(hdul[0].section, position=coord, size=2 * u.arcmin, wcs=WCS(hdul[0].header))

plt.figure(figsize=(10, 8))
plt.imshow(cutout.data, cmap='inferno')
plt.colorbar()
plt.title('Spitzer Image of Nebula NGC 602')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Simple image access queries from IRSA images from Spitzer telescope
coord = SkyCoord(ra=ra_hms, dec=dec_dms, unit=('hourangle', 'deg'), frame='icrs')
spitzer_images = Irsa.query_sia(pos=(coord, 1 * u.arcmin), collection='spitzer_seip').to_table()

# Open a cutout image for one of the science images
science_image = spitzer_images[spitzer_images['dataproduct_subtype'] == 'science'][1]
with fits.open(science_image['access_url'], use_fsspec=True) as hdul:
    cutout = Cutout2D(hdul[0].section, position=coord, size=2 * u.arcmin, wcs=WCS(hdul[0].header))

plt.figure(figsize=(10, 8))
plt.imshow(cutout.data, cmap='viridis')
plt.colorbar()
plt.title('Spitzer Image of Nebula NGC 602')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Simple image access queries from IRSA images from Spitzer telescope
coord = SkyCoord(ra=ra_hms, dec=dec_dms, unit=('hourangle', 'deg'), frame='icrs')
spitzer_images = Irsa.query_sia(pos=(coord, 1 * u.arcmin), collection='spitzer_seip').to_table()

# Open a cutout image for one of the science images
science_image = spitzer_images[spitzer_images['dataproduct_subtype'] == 'science'][1]
with fits.open(science_image['access_url'], use_fsspec=True) as hdul:
    cutout = Cutout2D(hdul[0].section, position=coord, size=2 * u.arcmin, wcs=WCS(hdul[0].header))

plt.figure(figsize=(10, 8))
plt.imshow(cutout.data, cmap='plasma')
plt.colorbar()
plt.title('Spitzer Image of Nebula NGC 602')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Simple image access queries from IRSA images from Spitzer telescope
coord = SkyCoord(ra=ra_hms, dec=dec_dms, unit=('hourangle', 'deg'), frame='icrs')
spitzer_images = Irsa.query_sia(pos=(coord, 1 * u.arcmin), collection='spitzer_seip').to_table()

# Open a cutout image for one of the science images
science_image = spitzer_images[spitzer_images['dataproduct_subtype'] == 'science'][1]
with fits.open(science_image['access_url'], use_fsspec=True) as hdul:
    cutout = Cutout2D(hdul[0].section, position=coord, size=2 * u.arcmin, wcs=WCS(hdul[0].header))

plt.figure(figsize=(10, 8))
plt.imshow(cutout.data, cmap='Pastel1')
plt.colorbar()
plt.title('Spitzer Image of Nebula NGC 602')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Simple image access queries from IRSA images from Spitzer telescope
coord = SkyCoord(ra=ra_hms, dec=dec_dms, unit=('hourangle', 'deg'), frame='icrs')
spitzer_images = Irsa.query_sia(pos=(coord, 1 * u.arcmin), collection='spitzer_seip').to_table()

# Open a cutout image for one of the science images
science_image = spitzer_images[spitzer_images['dataproduct_subtype'] == 'science'][2]
with fits.open(science_image['access_url'], use_fsspec=True) as hdul:
    cutout = Cutout2D(hdul[0].section, position=coord, size=2 * u.arcmin, wcs=WCS(hdul[0].header))

plt.figure(figsize=(10, 8))
plt.imshow(cutout.data, cmap='inferno')
plt.colorbar()
plt.title('Spitzer Image of Nebula NGC 602')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# How many science picture are therein spitzer_images?
science_images_count = len(spitzer_images[spitzer_images['dataproduct_subtype'] == 'science'])
print("Number of science images:", science_images_count)
# Out:
# Number of science images: 18
