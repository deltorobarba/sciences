# %% [markdown]
# <a href="https://colab.research.google.com/github/deltorobarba/sciences/blob/master/quasar_3C273.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Quasar 3C273**

# %% [markdown]
# https://de.m.wikipedia.org/wiki/3C_273

# %%
# !pip install astropy astroquery -q
from astroquery.ipac.irsa import Irsa
from astropy import units as u
from astropy.coordinates import SkyCoord
from astroquery.simbad import Simbad
from astropy import coordinates
from astropy.io import fits
from astropy.nddata import Cutout2D
from astropy.wcs import WCS
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.8/994.8 kB 7.8 MB/s eta 0:00:00

# %% [markdown]
# *Load data with FITS via IRSA (start with name, then get coordinates and FITS)*

# %%
# Define object (Galaxy name)
object_name = '3C273'

# %%
# Get skycoordinates of desired object
galaxy = Simbad.query_object(object_name)
ra_hms = galaxy['RA'][0]
dec_dms = galaxy['DEC'][0]
print(galaxy)
# Out:
# MAIN_ID       RA           DEC      RA_PREC ... COO_WAVELENGTH     COO_BIBCODE     SCRIPT_NUMBER_ID
#            "h:m:s"       "d:m:s"            ...
# ------- ------------- ------------- ------- ... -------------- ------------------- ----------------
#  3C 273 12 29 06.6998 +02 03 08.597      14 ...              O 2020yCat.1350....0G                1

# %%
print("RA (h:m:s):", ra_hms)
print("DEC (d:m:s):", dec_dms)
# Out:
# RA (h:m:s): 12 29 06.6998
# DEC (d:m:s): +02 03 08.597

# %%
# Simple image access queries from IRSA for galaxy images from Spitzer telescope
coord = SkyCoord(ra=ra_hms, dec=dec_dms, unit=('hourangle', 'deg'), frame='icrs')
spitzer_images = Irsa.query_sia(pos=(coord, 1 * u.arcmin), collection='spitzer_seip').to_table()

# Open a cutout image for one of the science images
science_image = spitzer_images[spitzer_images['dataproduct_subtype'] == 'science'][0]
with fits.open(science_image['access_url'], use_fsspec=True) as hdul:
    cutout = Cutout2D(hdul[0].section, position=coord, size=2 * u.arcmin, wcs=WCS(hdul[0].header))

plt.figure(figsize=(10, 8))
plt.imshow(cutout.data, cmap='viridis')
plt.colorbar()
plt.title(f'Spitzer Image of {object_name} galaxy')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Simple image access queries from IRSA for M31 galaxy images from Spitzer telescope
coord = SkyCoord(ra=ra_hms, dec=dec_dms, unit=('hourangle', 'deg'), frame='icrs')
spitzer_images = Irsa.query_sia(pos=(coord, 1 * u.arcmin), collection='spitzer_seip').to_table()

# Open a cutout image for one of the science images
science_image = spitzer_images[spitzer_images['dataproduct_subtype'] == 'science'][1]
with fits.open(science_image['access_url'], use_fsspec=True) as hdul:
    cutout = Cutout2D(hdul[0].section, position=coord, size=2 * u.arcmin, wcs=WCS(hdul[0].header))

plt.figure(figsize=(10, 8))
plt.imshow(cutout.data, cmap='viridis')
plt.colorbar()
plt.title(f'Spitzer Image of {object_name} galaxy')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Simple image access queries from IRSA for M31 galaxy images from Spitzer telescope
coord = SkyCoord(ra=ra_hms, dec=dec_dms, unit=('hourangle', 'deg'), frame='icrs')
spitzer_images = Irsa.query_sia(pos=(coord, 1 * u.arcmin), collection='spitzer_seip').to_table()

# Open a cutout image for one of the science images
science_image = spitzer_images[spitzer_images['dataproduct_subtype'] == 'science'][8]
with fits.open(science_image['access_url'], use_fsspec=True) as hdul:
    cutout = Cutout2D(hdul[0].section, position=coord, size=2 * u.arcmin, wcs=WCS(hdul[0].header))

plt.figure(figsize=(10, 8))
plt.imshow(cutout.data, cmap='inferno')
plt.colorbar()
plt.title(f'Spitzer Image of {object_name} galaxy')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Simple image access queries from IRSA for M31 galaxy images from Spitzer telescope
coord = SkyCoord(ra=ra_hms, dec=dec_dms, unit=('hourangle', 'deg'), frame='icrs')
spitzer_images = Irsa.query_sia(pos=(coord, 1 * u.arcmin), collection='spitzer_seip').to_table()

# Open a cutout image for one of the science images
science_image = spitzer_images[spitzer_images['dataproduct_subtype'] == 'science'][7]
with fits.open(science_image['access_url'], use_fsspec=True) as hdul:
    cutout = Cutout2D(hdul[0].section, position=coord, size=2 * u.arcmin, wcs=WCS(hdul[0].header))

plt.figure(figsize=(10, 8))
plt.imshow(cutout.data, cmap='plasma')
plt.colorbar()
plt.title(f'Spitzer Image of {object_name} galaxy')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# How many science picture are therein spitzer_images?
science_images_count = len(spitzer_images[spitzer_images['dataproduct_subtype'] == 'science'])
print("Number of science images:", science_images_count)
# Out:
# Number of science images: 10

# %%
import matplotlib.pyplot as plt
from astropy.wcs import WCS
from astropy.nddata import Cutout2D
from astropy.io import fits
import astropy.units as u
from astroquery.irsa import Irsa
from astropy.coordinates import SkyCoord

# Simple image access queries from IRSA for M31 galaxy images from Spitzer telescope
coord = SkyCoord(ra=ra_hms, dec=dec_dms, unit=('hourangle', 'deg'), frame='icrs')
spitzer_images = Irsa.query_sia(pos=(coord, 1 * u.arcmin), collection='spitzer_seip').to_table()

# Filter for science images only
science_images = spitzer_images[spitzer_images['dataproduct_subtype'] == 'science']

# Set up the figure for a 16x2 grid (2 images per row, 16 rows)
fig, axes = plt.subplots(5, 2, figsize=(10, 40))  # Adjust figsize for clarity

# Loop through each of the 14 science images of the total 32 images
for i in range(10):
    # Access each science image URL
    science_image = science_images[i]
    with fits.open(science_image['access_url'], use_fsspec=True) as hdul:
        cutout = Cutout2D(hdul[0].section, position=coord, size=2 * u.arcmin, wcs=WCS(hdul[0].header))

    # Plot the cutout in the grid
    ax = axes[i // 2, i % 2]  # Calculate row and column for 2 images per row
    ax.imshow(cutout.data, cmap='viridis')
    ax.axis('off')  # Hide axes for clarity

plt.title(f'Spitzer Image of {object_name} galaxy', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout for the title
plt.show()

# %% [markdown]
# **Get more details about the file**

# %%
hdul = fits.open(science_image['access_url'], use_fsspec=True)

# %%
# Print the file information
hdul.info()
# Out:
# Filename: <class 'fsspec.implementations.http.HTTPFile'>
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      77   (564, 774)   float32

# %%
#  Access the primary HDU (Header/Data Unit) to get the data
primary_hdu = hdul[0]
data = primary_hdu.data
print(primary_hdu.header) # Display the header to learn more about the file
print(repr(hdul[0].header))  # Science data HDU header
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel - floating point                NAXIS   =                    2 / Number of axes                                 NAXIS1  =                  564 / X axis length                                  NAXIS2  =                  774 / Y axis length                                  ORIGIN  = 'Spitzer Super-Mosaic Pipeline' / Origin of these image data          CREATOR = 'Spitzer Science Center' / Creator of this FITS file                                                                                                            / TIME AND EXPOSURE INFORMATION                                                                                                                       TELESCOP= 'Spitzer '           / Name of Telescope                              INSTRUME= 'MIPS    '           / Name of Instrument                             CHNLNUM =                    1 / Instrument channel number                      WAVELEN =                23.68 / [microns] effective wavelength of band / EffectMJDSTART=         53218.299493 / MJD of first observation in mosaic             MJDMEAN =         53218.308094 / Mean MJD of observations in mosaic             MJDMED  =            53218.309 / Median MJD of observations in mosaic           MJDEND  =         53218.313255 / MJD of last observation in mosaic              EXPTIME =               110.35 / Mean exposure time in seconds per pixel        MEXPTIME=                79.68 / Median exposure time in seconds per pixel      ETMIN   =                 2.62 / Minimum exposure time in seconds of input exposETMAX   =                 9.96 / Maximum exposure time in seconds of input exposCOV     =                29.49 / Mean coverage in exposures per pixel           MEDCOV  =                29.49 / Median coverage in exposures per pixel         SATMAX  =               76.336 / Soft saturation counts for shortest exposure inSATMIN  =               20.080 / Soft saturation counts for longest exposure / S                                                                                          / SUPER-MOSAIC DATA PRODUCT INFORMATION                                                                                                               IMTYPE  = 'median  '           / Image product type                             REGID   =             50058380 / Mosaic region identifier                       SUBREGID= '50058380-0'         / Sub-mosaic region identifier                   NXTILE  =                    1 / Number of sub-region tiles in X direction      NYTILE  =                    1 / Number of sub-region tiles in Y direction      XTILE   =                    0 / X position of sub-region tile                  YTILE   =                    0 / Y position of sub-region tile                  SMCASE  =                    4 / Super-Mosaic use-case                                                                                                                    / DATA PROCESSING INFORMATION                                                                                                                         OVRLPNL = 'overlap_gal_mips.nl' / Overlap correction namelist                   MOSNL   = 'mosaic_gal_mips.nl' / Mosaic namelist                                MOPEXVER= '18.5.4  '           / Version of MOPEX used for mosaic processing    PIPEVER = 'S18.12.0'           / Version of calibration pipeline for input imageSMVER   = '2.0     '           / Super-Mosaic pipeline version                  FCREATE = '2012-09-30T19:18:18' / File creation date/time (UTC)                                                                                                           / PHOTOMETRY                                                                                                                                          BUNIT   = 'MJy/sr  '           / Units for image counts                          ...
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel - floating point
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                  564 / X axis length
# NAXIS2  =                  774 / Y axis length
# ORIGIN  = 'Spitzer Super-Mosaic Pipeline' / Origin of these image data
# CREATOR = 'Spitzer Science Center' / Creator of this FITS file
#
#           / TIME AND EXPOSURE INFORMATION
#
# TELESCOP= 'Spitzer '           / Name of Telescope
# INSTRUME= 'MIPS    '           / Name of Instrument
# CHNLNUM =                    1 / Instrument channel number
# WAVELEN =                23.68 / [microns] effective wavelength of band / Effect
# MJDSTART=         53218.299493 / MJD of first observation in mosaic
# MJDMEAN =         53218.308094 / Mean MJD of observations in mosaic
# MJDMED  =            53218.309 / Median MJD of observations in mosaic
# MJDEND  =         53218.313255 / MJD of last observation in mosaic
# EXPTIME =               110.35 / Mean exposure time in seconds per pixel
# MEXPTIME=                79.68 / Median exposure time in seconds per pixel
# ETMIN   =                 2.62 / Minimum exposure time in seconds of input expos
# ETMAX   =                 9.96 / Maximum exposure time in seconds of input expos
# COV     =                29.49 / Mean coverage in exposures per pixel
# MEDCOV  =                29.49 / Median coverage in exposures per pixel
# SATMAX  =               76.336 / Soft saturation counts for shortest exposure in
# SATMIN  =               20.080 / Soft saturation counts for longest exposure / S
#
#           / SUPER-MOSAIC DATA PRODUCT INFORMATION
#
# IMTYPE  = 'median  '           / Image product type
# REGID   =             50058380 / Mosaic region identifier
# SUBREGID= '50058380-0'         / Sub-mosaic region identifier
# NXTILE  =                    1 / Number of sub-region tiles in X direction
# NYTILE  =                    1 / Number of sub-region tiles in Y direction
# XTILE   =                    0 / X position of sub-region tile
# YTILE   =                    0 / Y position of sub-region tile
# SMCASE  =                    4 / Super-Mosaic use-case
#
#           / DATA PROCESSING INFORMATION
#
# OVRLPNL = 'overlap_gal_mips.nl' / Overlap correction namelist
# MOSNL   = 'mosaic_gal_mips.nl' / Mosaic namelist
# MOPEXVER= '18.5.4  '           / Version of MOPEX used for mosaic processing
# PIPEVER = 'S18.12.0'           / Version of calibration pipeline for input image
# SMVER   = '2.0     '           / Super-Mosaic pipeline version
# FCREATE = '2012-09-30T19:18:18' / File creation date/time (UTC)
#
#           / PHOTOMETRY
#
# BUNIT   = 'MJy/sr  '           / Units for image counts
# GAIN    =             8229.008 / Mean conversion in e- / Mean conversion in e-/(
# EXPGAIN =                5.000 / e- / e-/DN for input exposures
# EFCONV  =               0.0447 / (MJy / (MJy/sr)/(DN/s) for input exposures
# ZPAB    =              18.5263 / Magnitude Zero-Point on AB System / Magnitude Z
# ZPVEGA  =              11.7293 / Magnitude Zero-Point on Vega System / Magnitude
#
#           / ASTROMETRY
#
# RADESYS = 'ICRS    '           / International Celestial Reference System
# CRVAL1  =            12.413907 / [deg] RA of reference point
# CRVAL2  =            32.291411 / [deg] DEC of reference point
# CRPIX1  =             282.5031 / [pix] Image reference point
# CRPIX2  =             387.7125 / [pix] Image reference point
# CTYPE1  = 'RA---TAN'           / RA projection type
# CTYPE2  = 'DEC--TAN'           / DEC projection type
# PA      =                  -0. / [deg] Position angle of axis 2 (E of N)
# CD1_1   =         -0.000680556 / Transformation matrix
# CD1_2   =                  -0.
# CD2_1   =                  -0.
# CD2_2   =          0.000680556
# PIXSCALE=                 2.45 / arcsec/pix
# EQUINOX =                2000. / [yr] Equatorial coordinates definition
#
#           / SKY BACKGROUND INFORMATION
#
# ISM_EST =                0.146 / Estimated mean ISM background MJy/str
# ZODY_EST=               26.432 / Estimated mean Zody background MJy/str

# %%
# Close the FITS file
hdul.close()
