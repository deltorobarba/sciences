# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from scipy.special import comb
from scipy.spatial.distance import pdist, squareform
from scipy.sparse.linalg import eigs
from itertools import product
import statistics

import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
def quantum_cost(n, E, r, gap, k, betti_k_minus_one):
  """Calculates Toffoli count given parameters to the TDA algorithm.
  Args:
    n: number of vertices
    E: number of edges
    gap: difference between lowest and second lowest eigenvalue of the k-th
      order combinatorial Laplacian
    k: order of Betti number
    betti_k_minus_one: Betti number of order k-1

  Returns:
    Toffoli count
  """
  return n * E * np.sqrt(comb(n, k) / betti_k_minus_one) / (r * gap)

# %%
def get_cliques_of_size(G, k):
  """Gets cliques of a graph.
  Args:
    G: `nx.Graph` problem graph
    k: order of Betti number being estimated

  Returns:
    A 3-tuple of `list`, respectively the cliques of size k-1, k and k+1
  """
  all_cliques = list(nx.enumerate_all_cliques(G))
  lower_cliques = list(filter(lambda x: len(x) == k-1, all_cliques))
  cliques = list(filter(lambda x: len(x) == k, all_cliques))
  upper_cliques = list(filter(lambda x: len(x) == k+1, all_cliques))

  return lower_cliques, cliques, upper_cliques

# %%
def is_upper_clique(clique, upper_clique):
  """Decides if two cliques are adjacent. They have to have difference 1 in size.
  Args:
    clique: the smaller clique
    upper_clique: the larger clique

  Returns:
    Whether upper_clique is clique appended by one number
  """
  return (len(upper_clique) - len(clique) == 1) and (len(set(upper_clique) - set(clique)) == 1)

# %%
def get_number_of_upper_cliques(clique, upper_cliques):
  """Gets number of upper cliques a clique has.
  Args:
    clique: the clique
    upper_cliques: a list with cliques of size 1 larger than clique

  Returns:
    The number of cliques in upper_cliques that are upper to clique.
  """
  total = 0
  for upper_clique in upper_cliques:
    if is_upper_clique(clique, upper_clique):
      total +=1

  return total

# %%
def lower_not_upper_similarity(clique1, clique2, lower_cliques, upper_cliques):
  """Calculates off-diagonal entries of combinatorial Laplacian.

  Args:
    clique1: k-clique indexing the row
    clique2: k-clique indexing the column
    lower_cliques: `list` of (k-1)-cliques 
    upper_cliques: `list` of (k+1)-cliques

  Returns:
    The off-diagonal entry at coordinate (clique1, clique2).
  """
  # have common upper?
  for upper_clique in upper_cliques:
    if is_upper_clique(clique1, upper_clique) and is_upper_clique(clique2, upper_clique):
      return 0

  # don't have common upper
  # have common lower?

  # NEW CODE
  # clique1 and clique2 are lower similar if and only if they differ on exactly one vertex
  # Sign is given by the parity of the number of different elements: odd --> +1, even --> -1
  if len(set(clique1).difference(set(clique2)))==1:
    return 2 * (np.count_nonzero(np.array(clique1) - np.array(clique2)) % 2) - 1

  # OLD CODE
  '''
  for lower_clique in lower_cliques:
    if is_upper_clique(lower_clique, clique1) and is_upper_clique(lower_clique, clique2):
     # have a common lower. Need to find similarity.

     diff_inds = []
     diff_elems1 = list(set(clique1) - set(clique2))
     diff_inds.append(clique1.index(diff_elems1[0]))

     diff_elems2 = list(set(clique2) - set(clique1))        
     diff_inds.append(clique2.index(diff_elems2[0]))

     if len(diff_inds) == 1:
       sign = 0
     else:  
       sign = ((diff_inds[1] - diff_inds[0]) % 2)

     return (-1) ** sign
  '''
  
  # don't have common lower
  return 0

# %%
### THIS IS ACTUALLY COMPUTING THE ORDER (k-1)
# returns the combinatorial Laplacian of order k of a graph
def get_laplacian(G, k):
  """Computes the k-th order Laplacian of a graph G using theorem 3.3.4 in
  http://www2.stat.duke.edu/~sayan/forkate/CombinatorialLaplacians.pdf.

  Args:
    G: `nx.Graph` input graph
    k: order of Betti number to be estimated

  Returns:
    The matrix of such combinatorial Laplacian.
  """
  # standard Laplacian
  if k==0:
    return nx.laplacian_matrix(G)

  #k += 1
  lower_cliques, cliques, upper_cliques = get_cliques_of_size(G, k)

  n_cliques = len(cliques)
  laplacian = np.zeros((n_cliques, n_cliques))
  for (row, clique_row) in enumerate(cliques):
    for (column, clique_column) in enumerate(cliques):
      # diagonal
      if row == column:
        #laplacian[row][column] = k + 1 + get_number_of_upper_cliques(clique_row, upper_cliques)
        laplacian[row][column] = k + get_number_of_upper_cliques(clique_row, upper_cliques)

      # off-diagonals
      else:
        laplacian[row][column] = lower_not_upper_similarity(clique_row, clique_column, lower_cliques, upper_cliques)

  return laplacian

# %%
def get_laplacian_spectrum(G, k):
  """Computes the eigenvalue spectrum of the k-th order Laplacian of a graph G

  Args:
    G: `nx.Graph` input graph
    k: order of the Betti number being estimated

  Returns:
    `list` of eigenvalues
  """
  laplacian = get_laplacian(G, k)
  eigvals = np.linalg.eigvals(laplacian)
  eigvals = np.sort(eigvals)
  
  return eigvals

# %%
# calculates combinatorial laplacian gap of a graph G at order k as well as the
# number of zero eigenvalues
def get_laplacian_info(G, k):
  """Computes the difference between the second lowest and lowest eigenvalues
  of the k-th order Laplacian of a graph G

  Args:
    G: `nx.Graph` input graph
    k: order of the Betti number being estimated

  Returns:
    The gap of the Laplacian and the number of zero eigenvalues.
  """
  '''
  laplacian = get_laplacian(G, k)
  eigvals = np.linalg.eigvals(laplacian)
  '''
  eigvals = get_laplacian_spectrum(G, k)
  eigvals = list(map(lambda x: 0 if np.abs(x) < 0.000000000001 else x, list(eigvals)))

  betti_number = eigvals.count(0)
  
  eigvals = np.unique(eigvals)

  return eigvals[1] - eigvals[0], betti_number

# %%
def generate_plots(ns, ks):
  """Generates plots of combinatorial laplacian gap, betti number and number
  of Toffolis for a combination of n's and k's.

  Args:
    ns: `list` of `int` of n's
    ks: `list` of `int` of n's
  """
  n_samples = 3000
  gaps = [[] for _ in range(len(ks))]
  gap_stds = [[] for _ in range(len(ks))]
  bettis = [[] for _ in range(len(ks))]
  betti_stds = [[] for _ in range(len(ks))]
  costs = [[] for _ in range(len(ks))]
  cost_stds = [[] for _ in range(len(ks))]

  for k_ind, k in enumerate(ks):
    for n in ns:
      p = n ** (- (2 * k + 1)/float(2 * k * (k + 1)))
      betti_samples = []
      cost_samples = []
      gap_samples = []
      for ind in range(n_samples):
        print(f'(k, n, sample) = ({k}, {n}, {ind})')
        G = nx.erdos_renyi_graph(n, p)
        gap, betti_number = get_laplacian_info(G, k)
        betti_samples.append(betti_number)
        gap_samples.append(gap)
        cost_samples.append(quantum_cost(n, G.number_of_edges(), 0.05, gap, k, betti_number))

      cost_avg = sum(cost_samples) / n_samples
      betti_avg = sum(betti_samples) / float(n_samples)
      gap_avg = sum(gap_samples) / n_samples

      cost_std = statistics.stdev(np.real(cost_samples))
      betti_std = statistics.stdev(np.real(betti_samples))
      gap_std = statistics.stdev(np.real(gap_samples))

      costs[k_ind].append(cost_avg)
      bettis[k_ind].append(betti_avg)
      gaps[k_ind].append(gap_avg)

      cost_stds[k_ind].append(cost_std)
      betti_stds[k_ind].append(betti_std)
      gap_stds[k_ind].append(gap_std)
  
  fig = plt.figure(figsize=(20, 10))

  #fig.subplots_adjust(hspace=0.4, wspace=0.4)

  ax_costs = fig.add_subplot(1,3,1)
  for k_ind, k in enumerate(ks):
    ax_costs.scatter(ns, costs[k_ind])
    ax_costs.set_xlabel('n')
    ax_costs.set_ylabel('number of Toffolis')
    ax_costs.errorbar(ns, costs[k_ind], yerr=cost_stds[k_ind])
  ax_costs.legend([f'$k = {k}$' for k in ks])

  ax_gaps = fig.add_subplot(1,3,2)
  for k_ind, k in enumerate(ks):
    ax_gaps.scatter(ns, gaps[k_ind])
    ax_gaps.set_xlabel('n')
    ax_gaps.set_ylabel('Gap')
    ax_gaps.errorbar(ns, gaps[k_ind], yerr=gap_stds[k_ind])
  ax_gaps.legend([f'$k = {k}$' for k in ks])

  ax_bettis = fig.add_subplot(1,3,3)
  for k_ind, k in enumerate(ks):
    ax_bettis.scatter(ns, bettis[k_ind])
    ax_bettis.set_xlabel('n')
    ax_bettis.set_ylabel('Betti number')
    ax_bettis.errorbar(ns, bettis[k_ind], yerr=betti_stds[k_ind])
  ax_bettis.legend([f'$k = {k}$' for k in ks])

  plt.tight_layout()
  plt.subplots_adjust()
  plt.show()

# %%
generate_plots([10, 15, 20, 25, 30], [1,2])
# Out:
# (k, n, sample) = (1, 10, 0)
# (k, n, sample) = (1, 10, 1)
# (k, n, sample) = (1, 10, 2)
# (k, n, sample) = (1, 10, 3)
# (k, n, sample) = (1, 10, 4)
# (k, n, sample) = (1, 10, 5)
# (k, n, sample) = (1, 10, 6)
# (k, n, sample) = (1, 10, 7)
# (k, n, sample) = (1, 10, 8)
# (k, n, sample) = (1, 10, 9)
# (k, n, sample) = (1, 10, 10)
# (k, n, sample) = (1, 10, 11)
# (k, n, sample) = (1, 10, 12)
# (k, n, sample) = (1, 10, 13)
# (k, n, sample) = (1, 10, 14)
# (k, n, sample) = (1, 10, 15)
# (k, n, sample) = (1, 10, 16)
# (k, n, sample) = (1, 10, 17)
# (k, n, sample) = (1, 10, 18)
# (k, n, sample) = (1, 10, 19)
# (k, n, sample) = (1, 10, 20)
# (k, n, sample) = (1, 10, 21)
# (k, n, sample) = (1, 10, 22)
# (k, n, sample) = (1, 10, 23)
# (k, n, sample) = (1, 10, 24)
# (k, n, sample) = (1, 10, 25)
# (k, n, sample) = (1, 10, 26)
# (k, n, sample) = (1, 10, 27)
# (k, n, sample) = (1, 10, 28)
# (k, n, sample) = (1, 10, 29)
# (k, n, sample) = (1, 10, 30)
# (k, n, sample) = (1, 10, 31)
# (k, n, sample) = (1, 10, 32)
# (k, n, sample) = (1, 10, 33)
# (k, n, sample) = (1, 10, 34)
# (k, n, sample) = (1, 10, 35)
# (k, n, sample) = (1, 10, 36)
# (k, n, sample) = (1, 10, 37)
# (k, n, sample) = (1, 10, 38)
# (k, n, sample) = (1, 10, 39)
# (k, n, sample) = (1, 10, 40)
# (k, n, sample) = (1, 10, 41)
# (k, n, sample) = (1, 10, 42)
# (k, n, sample) = (1, 10, 43)
# (k, n, sample) = (1, 10, 44)
# (k, n, sample) = (1, 10, 45)
# (k, n, sample) = (1, 10, 46)
# (k, n, sample) = (1, 10, 47)
# (k, n, sample) = (1, 10, 48)
# (k, n, sample) = (1, 10, 49)
# (k, n, sample) = (1, 10, 50)
# (k, n, sample) = (1, 10, 51)
# (k, n, sample) = (1, 10, 52)
# (k, n, sample) = (1, 10, 53)
# (k, n, sample) = (1, 10, 54)
# (k, n, sample) = (1, 10, 55)
# (k, n, sample) = (1, 10, 56)
# (k, n, sample) = (1, 10, 57)
# (k, n, sample) = (1, 10, 58)
# (k, n, sample) = (1, 10, 59)
# (k, n, sample) = (1, 10, 60)
# (k, n, sample) = (1, 10, 61)
# (k, n, sample) = (1, 10, 62)
# (k, n, sample) = (1, 10, 63)
# (k, n, sample) = (1, 10, 64)
# (k, n, sample) = (1, 10, 65)
# (k, n, sample) = (1, 10, 66)
# (k, n, sample) = (1, 10, 67)
# (k, n, sample) = (1, 10, 68)
# (k, n, sample) = (1, 10, 69)
# (k, n, sample) = (1, 10, 70)
# (k, n, sample) = (1, 10, 71)
# (k, n, sample) = (1, 10, 72)
# (k, n, sample) = (1, 10, 73)
# (k, n, sample) = (1, 10, 74)
# (k, n, sample) = (1, 10, 75)
# (k, n, sample) = (1, 10, 76)
# (k, n, sample) = (1, 10, 77)
# (k, n, sample) = (1, 10, 78)
# (k, n, sample) = (1, 10, 79)
# (k, n, sample) = (1, 10, 80)
# (k, n, sample) = (1, 10, 81)
# (k, n, sample) = (1, 10, 82)
# (k, n, sample) = (1, 10, 83)
# (k, n, sample) = (1, 10, 84)
# (k, n, sample) = (1, 10, 85)
# (k, n, sample) = (1, 10, 86)
# (k, n, sample) = (1, 10, 87)
# (k, n, sample) = (1, 10, 88)
# (k, n, sample) = (1, 10, 89)
# (k, n, sample) = (1, 10, 90)
# (k, n, sample) = (1, 10, 91)
# (k, n, sample) = (1, 10, 92)
# (k, n, sample) = (1, 10, 93)
# (k, n, sample) = (1, 10, 94)
# (k, n, sample) = (1, 10, 95)
# (k, n, sample) = (1, 10, 96)
# (k, n, sample) = (1, 10, 97)
# (k, n, sample) = (1, 10, 98)
# (k, n, sample) = (1, 10, 99)
# (k, n, sample) = (1, 10, 100)
# (k, n, sample) = (1, 10, 101)
# (k, n, sample) = (1, 10, 102)
# (k, n, sample) = (1, 10, 103)
# (k, n, sample) = (1, 10, 104)
# (k, n, sample) = (1, 10, 105)
# (k, n, sample) = (1, 10, 106)
# (k, n, sample) = (1, 10, 107)
# (k, n, sample) = (1, 10, 108)
# (k, n, sample) = (1, 10, 109)
# (k, n, sample) = (1, 10, 110)
# (k, n, sample) = (1, 10, 111)
# (k, n, sample) = (1, 10, 112)
# (k, n, sample) = (1, 10, 113)
# (k, n, sample) = (1, 10, 114)
# (k, n, sample) = (1, 10, 115)
# (k, n, sample) = (1, 10, 116)
# (k, n, sample) = (1, 10, 117)
# (k, n, sample) = (1, 10, 118)
# (k, n, sample) = (1, 10, 119)
# (k, n, sample) = (1, 10, 120)
# (k, n, sample) = (1, 10, 121)
# (k, n, sample) = (1, 10, 122)
# (k, n, sample) = (1, 10, 123)
# (k, n, sample) = (1, 10, 124)
# (k, n, sample) = (1, 10, 125)
# (k, n, sample) = (1, 10, 126)
# (k, n, sample) = (1, 10, 127)
# (k, n, sample) = (1, 10, 128)
# (k, n, sample) = (1, 10, 129)
# (k, n, sample) = (1, 10, 130)
# (k, n, sample) = (1, 10, 131)
# (k, n, sample) = (1, 10, 132)
# (k, n, sample) = (1, 10, 133)
# (k, n, sample) = (1, 10, 134)
# (k, n, sample) = (1, 10, 135)
# (k, n, sample) = (1, 10, 136)
# (k, n, sample) = (1, 10, 137)
# (k, n, sample) = (1, 10, 138)
# (k, n, sample) = (1, 10, 139)
# (k, n, sample) = (1, 10, 140)
# (k, n, sample) = (1, 10, 141)
# (k, n, sample) = (1, 10, 142)
# (k, n, sample) = (1, 10, 143)
# (k, n, sample) = (1, 10, 144)
# (k, n, sample) = (1, 10, 145)
# (k, n, sample) = (1, 10, 146)
# (k, n, sample) = (1, 10, 147)
# (k, n, sample) = (1, 10, 148)
# (k, n, sample) = (1, 10, 149)
# (k, n, sample) = (1, 10, 150)
# (k, n, sample) = (1, 10, 151)
# (k, n, sample) = (1, 10, 152)
# (k, n, sample) = (1, 10, 153)
# (k, n, sample) = (1, 10, 154)
# (k, n, sample) = (1, 10, 155)
# (k, n, sample) = (1, 10, 156)
# (k, n, sample) = (1, 10, 157)
# (k, n, sample) = (1, 10, 158)
# (k, n, sample) = (1, 10, 159)
# (k, n, sample) = (1, 10, 160)
# (k, n, sample) = (1, 10, 161)
# (k, n, sample) = (1, 10, 162)
# (k, n, sample) = (1, 10, 163)
# (k, n, sample) = (1, 10, 164)
# (k, n, sample) = (1, 10, 165)
# (k, n, sample) = (1, 10, 166)
# (k, n, sample) = (1, 10, 167)
# (k, n, sample) = (1, 10, 168)
# (k, n, sample) = (1, 10, 169)
# (k, n, sample) = (1, 10, 170)
# (k, n, sample) = (1, 10, 171)
# (k, n, sample) = (1, 10, 172)
# (k, n, sample) = (1, 10, 173)
# (k, n, sample) = (1, 10, 174)
# (k, n, sample) = (1, 10, 175)
# (k, n, sample) = (1, 10, 176)
# (k, n, sample) = (1, 10, 177)
# (k, n, sample) = (1, 10, 178)
# (k, n, sample) = (1, 10, 179)
# (k, n, sample) = (1, 10, 180)
# (k, n, sample) = (1, 10, 181)
# (k, n, sample) = (1, 10, 182)
# (k, n, sample) = (1, 10, 183)
# (k, n, sample) = (1, 10, 184)
# (k, n, sample) = (1, 10, 185)
# (k, n, sample) = (1, 10, 186)
# (k, n, sample) = (1, 10, 187)
# (k, n, sample) = (1, 10, 188)
# (k, n, sample) = (1, 10, 189)
# (k, n, sample) = (1, 10, 190)
# (k, n, sample) = (1, 10, 191)
# (k, n, sample) = (1, 10, 192)
# (k, n, sample) = (1, 10, 193)
# (k, n, sample) = (1, 10, 194)
# (k, n, sample) = (1, 10, 195)
# (k, n, sample) = (1, 10, 196)
# (k, n, sample) = (1, 10, 197)
# (k, n, sample) = (1, 10, 198)
# (k, n, sample) = (1, 10, 199)
# (k, n, sample) = (1, 10, 200)
# (k, n, sample) = (1, 10, 201)
# (k, n, sample) = (1, 10, 202)
# (k, n, sample) = (1, 10, 203)
# (k, n, sample) = (1, 10, 204)
# (k, n, sample) = (1, 10, 205)
# (k, n, sample) = (1, 10, 206)
# (k, n, sample) = (1, 10, 207)
# (k, n, sample) = (1, 10, 208)
# (k, n, sample) = (1, 10, 209)
# (k, n, sample) = (1, 10, 210)
# (k, n, sample) = (1, 10, 211)
# (k, n, sample) = (1, 10, 212)
# (k, n, sample) = (1, 10, 213)
# (k, n, sample) = (1, 10, 214)
# (k, n, sample) = (1, 10, 215)
# (k, n, sample) = (1, 10, 216)
# (k, n, sample) = (1, 10, 217)
# (k, n, sample) = (1, 10, 218)
# (k, n, sample) = (1, 10, 219)
# (k, n, sample) = (1, 10, 220)
# (k, n, sample) = (1, 10, 221)
# (k, n, sample) = (1, 10, 222)
# (k, n, sample) = (1, 10, 223)
# (k, n, sample) = (1, 10, 224)
# (k, n, sample) = (1, 10, 225)
# (k, n, sample) = (1, 10, 226)
# (k, n, sample) = (1, 10, 227)
# (k, n, sample) = (1, 10, 228)
# (k, n, sample) = (1, 10, 229)
# (k, n, sample) = (1, 10, 230)
# (k, n, sample) = (1, 10, 231)
# (k, n, sample) = (1, 10, 232)
# (k, n, sample) = (1, 10, 233)
# (k, n, sample) = (1, 10, 234)
# (k, n, sample) = (1, 10, 235)
# (k, n, sample) = (1, 10, 236)
# (k, n, sample) = (1, 10, 237)
# (k, n, sample) = (1, 10, 238)
# (k, n, sample) = (1, 10, 239)
# (k, n, sample) = (1, 10, 240)
# (k, n, sample) = (1, 10, 241)
# (k, n, sample) = (1, 10, 242)
# (k, n, sample) = (1, 10, 243)
# (k, n, sample) = (1, 10, 244)
# (k, n, sample) = (1, 10, 245)
# (k, n, sample) = (1, 10, 246)
# (k, n, sample) = (1, 10, 247)
# (k, n, sample) = (1, 10, 248)
# (k, n, sample) = (1, 10, 249)
# (k, n, sample) = (1, 10, 250)
# (k, n, sample) = (1, 10, 251)
# (k, n, sample) = (1, 10, 252)
# (k, n, sample) = (1, 10, 253)
# (k, n, sample) = (1, 10, 254)
# (k, n, sample) = (1, 10, 255)
# (k, n, sample) = (1, 10, 256)
# (k, n, sample) = (1, 10, 257)
# (k, n, sample) = (1, 10, 258)
# (k, n, sample) = (1, 10, 259)
# (k, n, sample) = (1, 10, 260)
# (k, n, sample) = (1, 10, 261)
# (k, n, sample) = (1, 10, 262)
# (k, n, sample) = (1, 10, 263)
# (k, n, sample) = (1, 10, 264)
# (k, n, sample) = (1, 10, 265)
# (k, n, sample) = (1, 10, 266)
# (k, n, sample) = (1, 10, 267)
# (k, n, sample) = (1, 10, 268)
# (k, n, sample) = (1, 10, 269)
# (k, n, sample) = (1, 10, 270)
# (k, n, sample) = (1, 10, 271)
# (k, n, sample) = (1, 10, 272)
# (k, n, sample) = (1, 10, 273)
# (k, n, sample) = (1, 10, 274)
# (k, n, sample) = (1, 10, 275)
# (k, n, sample) = (1, 10, 276)
# (k, n, sample) = (1, 10, 277)
# (k, n, sample) = (1, 10, 278)
# (k, n, sample) = (1, 10, 279)
# (k, n, sample) = (1, 10, 280)
# (k, n, sample) = (1, 10, 281)
# (k, n, sample) = (1, 10, 282)
# (k, n, sample) = (1, 10, 283)
# (k, n, sample) = (1, 10, 284)
# (k, n, sample) = (1, 10, 285)
# (k, n, sample) = (1, 10, 286)
# (k, n, sample) = (1, 10, 287)
# (k, n, sample) = (1, 10, 288)
# (k, n, sample) = (1, 10, 289)
# (k, n, sample) = (1, 10, 290)
# (k, n, sample) = (1, 10, 291)
# (k, n, sample) = (1, 10, 292)
# (k, n, sample) = (1, 10, 293)
# (k, n, sample) = (1, 10, 294)
# (k, n, sample) = (1, 10, 295)
# (k, n, sample) = (1, 10, 296)
# (k, n, sample) = (1, 10, 297)
# (k, n, sample) = (1, 10, 298)
# (k, n, sample) = (1, 10, 299)
# (k, n, sample) = (1, 10, 300)
# (k, n, sample) = (1, 10, 301)
# (k, n, sample) = (1, 10, 302)
# (k, n, sample) = (1, 10, 303)
# (k, n, sample) = (1, 10, 304)
# (k, n, sample) = (1, 10, 305)
# (k, n, sample) = (1, 10, 306)
# (k, n, sample) = (1, 10, 307)
# (k, n, sample) = (1, 10, 308)
# (k, n, sample) = (1, 10, 309)
# (k, n, sample) = (1, 10, 310)
# (k, n, sample) = (1, 10, 311)
# (k, n, sample) = (1, 10, 312)
# (k, n, sample) = (1, 10, 313)
# (k, n, sample) = (1, 10, 314)
# (k, n, sample) = (1, 10, 315)
# (k, n, sample) = (1, 10, 316)
# (k, n, sample) = (1, 10, 317)
# (k, n, sample) = (1, 10, 318)
# (k, n, sample) = (1, 10, 319)
# (k, n, sample) = (1, 10, 320)
# (k, n, sample) = (1, 10, 321)
# (k, n, sample) = (1, 10, 322)
# (k, n, sample) = (1, 10, 323)
# (k, n, sample) = (1, 10, 324)
# (k, n, sample) = (1, 10, 325)
# (k, n, sample) = (1, 10, 326)
# (k, n, sample) = (1, 10, 327)
# (k, n, sample) = (1, 10, 328)
# (k, n, sample) = (1, 10, 329)
# (k, n, sample) = (1, 10, 330)
# (k, n, sample) = (1, 10, 331)
# (k, n, sample) = (1, 10, 332)
# (k, n, sample) = (1, 10, 333)
# (k, n, sample) = (1, 10, 334)
# (k, n, sample) = (1, 10, 335)
# (k, n, sample) = (1, 10, 336)
# (k, n, sample) = (1, 10, 337)
# (k, n, sample) = (1, 10, 338)
# (k, n, sample) = (1, 10, 339)
# (k, n, sample) = (1, 10, 340)
# (k, n, sample) = (1, 10, 341)
# (k, n, sample) = (1, 10, 342)
# (k, n, sample) = (1, 10, 343)
# (k, n, sample) = (1, 10, 344)
# (k, n, sample) = (1, 10, 345)
# (k, n, sample) = (1, 10, 346)
# (k, n, sample) = (1, 10, 347)
# (k, n, sample) = (1, 10, 348)
# (k, n, sample) = (1, 10, 349)
# (k, n, sample) = (1, 10, 350)
# (k, n, sample) = (1, 10, 351)
# (k, n, sample) = (1, 10, 352)
# (k, n, sample) = (1, 10, 353)
# (k, n, sample) = (1, 10, 354)
# (k, n, sample) = (1, 10, 355)
# (k, n, sample) = (1, 10, 356)
# (k, n, sample) = (1, 10, 357)
# (k, n, sample) = (1, 10, 358)
# (k, n, sample) = (1, 10, 359)
# (k, n, sample) = (1, 10, 360)
# (k, n, sample) = (1, 10, 361)
# (k, n, sample) = (1, 10, 362)
# (k, n, sample) = (1, 10, 363)
# (k, n, sample) = (1, 10, 364)
# (k, n, sample) = (1, 10, 365)
# (k, n, sample) = (1, 10, 366)
# (k, n, sample) = (1, 10, 367)
# (k, n, sample) = (1, 10, 368)
# (k, n, sample) = (1, 10, 369)
# (k, n, sample) = (1, 10, 370)
# (k, n, sample) = (1, 10, 371)
# (k, n, sample) = (1, 10, 372)
# (k, n, sample) = (1, 10, 373)
# (k, n, sample) = (1, 10, 374)
# (k, n, sample) = (1, 10, 375)
# (k, n, sample) = (1, 10, 376)
# (k, n, sample) = (1, 10, 377)
# (k, n, sample) = (1, 10, 378)
# (k, n, sample) = (1, 10, 379)
# (k, n, sample) = (1, 10, 380)
# (k, n, sample) = (1, 10, 381)
# (k, n, sample) = (1, 10, 382)
# (k, n, sample) = (1, 10, 383)
# (k, n, sample) = (1, 10, 384)
# (k, n, sample) = (1, 10, 385)
# (k, n, sample) = (1, 10, 386)
# (k, n, sample) = (1, 10, 387)
# (k, n, sample) = (1, 10, 388)
# (k, n, sample) = (1, 10, 389)
# (k, n, sample) = (1, 10, 390)
# (k, n, sample) = (1, 10, 391)
# (k, n, sample) = (1, 10, 392)
# (k, n, sample) = (1, 10, 393)
# (k, n, sample) = (1, 10, 394)
# (k, n, sample) = (1, 10, 395)
# (k, n, sample) = (1, 10, 396)
# (k, n, sample) = (1, 10, 397)
# (k, n, sample) = (1, 10, 398)
# (k, n, sample) = (1, 10, 399)
# (k, n, sample) = (1, 10, 400)
# (k, n, sample) = (1, 10, 401)
# (k, n, sample) = (1, 10, 402)
# (k, n, sample) = (1, 10, 403)
# (k, n, sample) = (1, 10, 404)
# (k, n, sample) = (1, 10, 405)
# (k, n, sample) = (1, 10, 406)
# (k, n, sample) = (1, 10, 407)
# (k, n, sample) = (1, 10, 408)
# (k, n, sample) = (1, 10, 409)
# (k, n, sample) = (1, 10, 410)
# (k, n, sample) = (1, 10, 411)
# (k, n, sample) = (1, 10, 412)
# (k, n, sample) = (1, 10, 413)
# (k, n, sample) = (1, 10, 414)
# (k, n, sample) = (1, 10, 415)
# (k, n, sample) = (1, 10, 416)
# (k, n, sample) = (1, 10, 417)
# (k, n, sample) = (1, 10, 418)
# (k, n, sample) = (1, 10, 419)
# (k, n, sample) = (1, 10, 420)
# (k, n, sample) = (1, 10, 421)
# (k, n, sample) = (1, 10, 422)
# (k, n, sample) = (1, 10, 423)
# (k, n, sample) = (1, 10, 424)
# (k, n, sample) = (1, 10, 425)
# (k, n, sample) = (1, 10, 426)
# (k, n, sample) = (1, 10, 427)
# (k, n, sample) = (1, 10, 428)
# (k, n, sample) = (1, 10, 429)
# (k, n, sample) = (1, 10, 430)
# (k, n, sample) = (1, 10, 431)
# (k, n, sample) = (1, 10, 432)
# (k, n, sample) = (1, 10, 433)
# (k, n, sample) = (1, 10, 434)
# (k, n, sample) = (1, 10, 435)
# (k, n, sample) = (1, 10, 436)
# (k, n, sample) = (1, 10, 437)
# (k, n, sample) = (1, 10, 438)
# (k, n, sample) = (1, 10, 439)
# (k, n, sample) = (1, 10, 440)
# (k, n, sample) = (1, 10, 441)
# (k, n, sample) = (1, 10, 442)
# (k, n, sample) = (1, 10, 443)
# (k, n, sample) = (1, 10, 444)
# (k, n, sample) = (1, 10, 445)
# (k, n, sample) = (1, 10, 446)
# (k, n, sample) = (1, 10, 447)
# (k, n, sample) = (1, 10, 448)
# (k, n, sample) = (1, 10, 449)
# (k, n, sample) = (1, 10, 450)
# (k, n, sample) = (1, 10, 451)
# (k, n, sample) = (1, 10, 452)
# (k, n, sample) = (1, 10, 453)
# (k, n, sample) = (1, 10, 454)
# (k, n, sample) = (1, 10, 455)
# (k, n, sample) = (1, 10, 456)
# (k, n, sample) = (1, 10, 457)
# (k, n, sample) = (1, 10, 458)
# (k, n, sample) = (1, 10, 459)
# (k, n, sample) = (1, 10, 460)
# (k, n, sample) = (1, 10, 461)
# (k, n, sample) = (1, 10, 462)
# (k, n, sample) = (1, 10, 463)
# (k, n, sample) = (1, 10, 464)
# (k, n, sample) = (1, 10, 465)
# (k, n, sample) = (1, 10, 466)
# (k, n, sample) = (1, 10, 467)
# (k, n, sample) = (1, 10, 468)
# (k, n, sample) = (1, 10, 469)
# (k, n, sample) = (1, 10, 470)
# (k, n, sample) = (1, 10, 471)
# (k, n, sample) = (1, 10, 472)
# (k, n, sample) = (1, 10, 473)
# (k, n, sample) = (1, 10, 474)
# (k, n, sample) = (1, 10, 475)
# (k, n, sample) = (1, 10, 476)
# (k, n, sample) = (1, 10, 477)
# (k, n, sample) = (1, 10, 478)
# (k, n, sample) = (1, 10, 479)
# (k, n, sample) = (1, 10, 480)
# (k, n, sample) = (1, 10, 481)
# (k, n, sample) = (1, 10, 482)
# (k, n, sample) = (1, 10, 483)
# (k, n, sample) = (1, 10, 484)
# (k, n, sample) = (1, 10, 485)
# (k, n, sample) = (1, 10, 486)
# (k, n, sample) = (1, 10, 487)
# (k, n, sample) = (1, 10, 488)
# (k, n, sample) = (1, 10, 489)
# (k, n, sample) = (1, 10, 490)
# (k, n, sample) = (1, 10, 491)
# (k, n, sample) = (1, 10, 492)
# (k, n, sample) = (1, 10, 493)
# (k, n, sample) = (1, 10, 494)
# (k, n, sample) = (1, 10, 495)
# (k, n, sample) = (1, 10, 496)
# (k, n, sample) = (1, 10, 497)
# (k, n, sample) = (1, 10, 498)
# (k, n, sample) = (1, 10, 499)
# (k, n, sample) = (1, 10, 500)
# (k, n, sample) = (1, 10, 501)
# (k, n, sample) = (1, 10, 502)
# (k, n, sample) = (1, 10, 503)
# (k, n, sample) = (1, 10, 504)
# (k, n, sample) = (1, 10, 505)
# (k, n, sample) = (1, 10, 506)
# (k, n, sample) = (1, 10, 507)
# (k, n, sample) = (1, 10, 508)
# (k, n, sample) = (1, 10, 509)
# (k, n, sample) = (1, 10, 510)
# (k, n, sample) = (1, 10, 511)
# (k, n, sample) = (1, 10, 512)
# (k, n, sample) = (1, 10, 513)
# (k, n, sample) = (1, 10, 514)
# (k, n, sample) = (1, 10, 515)
# (k, n, sample) = (1, 10, 516)
# (k, n, sample) = (1, 10, 517)
# (k, n, sample) = (1, 10, 518)
# (k, n, sample) = (1, 10, 519)
# (k, n, sample) = (1, 10, 520)
# (k, n, sample) = (1, 10, 521)
# (k, n, sample) = (1, 10, 522)
# (k, n, sample) = (1, 10, 523)
# (k, n, sample) = (1, 10, 524)
# (k, n, sample) = (1, 10, 525)
# (k, n, sample) = (1, 10, 526)
# (k, n, sample) = (1, 10, 527)
# (k, n, sample) = (1, 10, 528)
# (k, n, sample) = (1, 10, 529)
# (k, n, sample) = (1, 10, 530)
# (k, n, sample) = (1, 10, 531)
# (k, n, sample) = (1, 10, 532)
# (k, n, sample) = (1, 10, 533)
# (k, n, sample) = (1, 10, 534)
# (k, n, sample) = (1, 10, 535)
# (k, n, sample) = (1, 10, 536)
# (k, n, sample) = (1, 10, 537)
# (k, n, sample) = (1, 10, 538)
# (k, n, sample) = (1, 10, 539)
# (k, n, sample) = (1, 10, 540)
# (k, n, sample) = (1, 10, 541)
# (k, n, sample) = (1, 10, 542)
# (k, n, sample) = (1, 10, 543)
# (k, n, sample) = (1, 10, 544)
# (k, n, sample) = (1, 10, 545)
# (k, n, sample) = (1, 10, 546)
# (k, n, sample) = (1, 10, 547)
# (k, n, sample) = (1, 10, 548)
# (k, n, sample) = (1, 10, 549)
# (k, n, sample) = (1, 10, 550)
# (k, n, sample) = (1, 10, 551)
# (k, n, sample) = (1, 10, 552)
# (k, n, sample) = (1, 10, 553)
# (k, n, sample) = (1, 10, 554)
# (k, n, sample) = (1, 10, 555)
# (k, n, sample) = (1, 10, 556)
# (k, n, sample) = (1, 10, 557)
# (k, n, sample) = (1, 10, 558)
# (k, n, sample) = (1, 10, 559)
# (k, n, sample) = (1, 10, 560)
# (k, n, sample) = (1, 10, 561)
# (k, n, sample) = (1, 10, 562)
# (k, n, sample) = (1, 10, 563)
# (k, n, sample) = (1, 10, 564)
# (k, n, sample) = (1, 10, 565)
# (k, n, sample) = (1, 10, 566)
# (k, n, sample) = (1, 10, 567)
# (k, n, sample) = (1, 10, 568)
# (k, n, sample) = (1, 10, 569)
# (k, n, sample) = (1, 10, 570)
# (k, n, sample) = (1, 10, 571)
# (k, n, sample) = (1, 10, 572)
# (k, n, sample) = (1, 10, 573)
# (k, n, sample) = (1, 10, 574)
# (k, n, sample) = (1, 10, 575)
# (k, n, sample) = (1, 10, 576)
# (k, n, sample) = (1, 10, 577)
# (k, n, sample) = (1, 10, 578)
# (k, n, sample) = (1, 10, 579)
# (k, n, sample) = (1, 10, 580)
# (k, n, sample) = (1, 10, 581)
# (k, n, sample) = (1, 10, 582)
# (k, n, sample) = (1, 10, 583)
# (k, n, sample) = (1, 10, 584)
# (k, n, sample) = (1, 10, 585)
# (k, n, sample) = (1, 10, 586)
# (k, n, sample) = (1, 10, 587)
# (k, n, sample) = (1, 10, 588)
# (k, n, sample) = (1, 10, 589)
# (k, n, sample) = (1, 10, 590)
# (k, n, sample) = (1, 10, 591)
# (k, n, sample) = (1, 10, 592)
# (k, n, sample) = (1, 10, 593)
# (k, n, sample) = (1, 10, 594)
# (k, n, sample) = (1, 10, 595)
# (k, n, sample) = (1, 10, 596)
# (k, n, sample) = (1, 10, 597)
# (k, n, sample) = (1, 10, 598)
# (k, n, sample) = (1, 10, 599)
# (k, n, sample) = (1, 10, 600)
# (k, n, sample) = (1, 10, 601)
# (k, n, sample) = (1, 10, 602)
# (k, n, sample) = (1, 10, 603)
# (k, n, sample) = (1, 10, 604)
# (k, n, sample) = (1, 10, 605)
# (k, n, sample) = (1, 10, 606)
# (k, n, sample) = (1, 10, 607)
# (k, n, sample) = (1, 10, 608)
# (k, n, sample) = (1, 10, 609)
# (k, n, sample) = (1, 10, 610)
# (k, n, sample) = (1, 10, 611)
# (k, n, sample) = (1, 10, 612)
# (k, n, sample) = (1, 10, 613)
# (k, n, sample) = (1, 10, 614)
# (k, n, sample) = (1, 10, 615)
# (k, n, sample) = (1, 10, 616)
# (k, n, sample) = (1, 10, 617)
# (k, n, sample) = (1, 10, 618)
# (k, n, sample) = (1, 10, 619)
# (k, n, sample) = (1, 10, 620)
# (k, n, sample) = (1, 10, 621)
# (k, n, sample) = (1, 10, 622)
# (k, n, sample) = (1, 10, 623)
# (k, n, sample) = (1, 10, 624)
# (k, n, sample) = (1, 10, 625)
# (k, n, sample) = (1, 10, 626)
# (k, n, sample) = (1, 10, 627)
# (k, n, sample) = (1, 10, 628)
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in double_scalars
# (k, n, sample) = (1, 10, 629)
# (k, n, sample) = (1, 10, 630)
# (k, n, sample) = (1, 10, 631)
# (k, n, sample) = (1, 10, 632)
# (k, n, sample) = (1, 10, 633)
# (k, n, sample) = (1, 10, 634)
# (k, n, sample) = (1, 10, 635)
# (k, n, sample) = (1, 10, 636)
# (k, n, sample) = (1, 10, 637)
# (k, n, sample) = (1, 10, 638)
# (k, n, sample) = (1, 10, 639)
# (k, n, sample) = (1, 10, 640)
# (k, n, sample) = (1, 10, 641)
# (k, n, sample) = (1, 10, 642)
# (k, n, sample) = (1, 10, 643)
# (k, n, sample) = (1, 10, 644)
# (k, n, sample) = (1, 10, 645)
# (k, n, sample) = (1, 10, 646)
# (k, n, sample) = (1, 10, 647)
# (k, n, sample) = (1, 10, 648)
# (k, n, sample) = (1, 10, 649)
# (k, n, sample) = (1, 10, 650)
# (k, n, sample) = (1, 10, 651)
# (k, n, sample) = (1, 10, 652)
# (k, n, sample) = (1, 10, 653)
# (k, n, sample) = (1, 10, 654)
# (k, n, sample) = (1, 10, 655)
# (k, n, sample) = (1, 10, 656)
# (k, n, sample) = (1, 10, 657)
# (k, n, sample) = (1, 10, 658)
# (k, n, sample) = (1, 10, 659)
# (k, n, sample) = (1, 10, 660)
# (k, n, sample) = (1, 10, 661)
# (k, n, sample) = (1, 10, 662)
# (k, n, sample) = (1, 10, 663)
# (k, n, sample) = (1, 10, 664)
# (k, n, sample) = (1, 10, 665)
# (k, n, sample) = (1, 10, 666)
# (k, n, sample) = (1, 10, 667)
# (k, n, sample) = (1, 10, 668)
# (k, n, sample) = (1, 10, 669)
# (k, n, sample) = (1, 10, 670)
# (k, n, sample) = (1, 10, 671)
# (k, n, sample) = (1, 10, 672)
# (k, n, sample) = (1, 10, 673)
# (k, n, sample) = (1, 10, 674)
# (k, n, sample) = (1, 10, 675)
# (k, n, sample) = (1, 10, 676)
# (k, n, sample) = (1, 10, 677)
# (k, n, sample) = (1, 10, 678)
# (k, n, sample) = (1, 10, 679)
# (k, n, sample) = (1, 10, 680)
# (k, n, sample) = (1, 10, 681)
# (k, n, sample) = (1, 10, 682)
# (k, n, sample) = (1, 10, 683)
# (k, n, sample) = (1, 10, 684)
# (k, n, sample) = (1, 10, 685)
# (k, n, sample) = (1, 10, 686)
# (k, n, sample) = (1, 10, 687)
# (k, n, sample) = (1, 10, 688)
# (k, n, sample) = (1, 10, 689)
# (k, n, sample) = (1, 10, 690)
# (k, n, sample) = (1, 10, 691)
# (k, n, sample) = (1, 10, 692)
# (k, n, sample) = (1, 10, 693)
# (k, n, sample) = (1, 10, 694)
# (k, n, sample) = (1, 10, 695)
# (k, n, sample) = (1, 10, 696)
# (k, n, sample) = (1, 10, 697)
# (k, n, sample) = (1, 10, 698)
# (k, n, sample) = (1, 10, 699)
# (k, n, sample) = (1, 10, 700)
# (k, n, sample) = (1, 10, 701)
# (k, n, sample) = (1, 10, 702)
# (k, n, sample) = (1, 10, 703)
# (k, n, sample) = (1, 10, 704)
# (k, n, sample) = (1, 10, 705)
# (k, n, sample) = (1, 10, 706)
# (k, n, sample) = (1, 10, 707)
# (k, n, sample) = (1, 10, 708)
# (k, n, sample) = (1, 10, 709)
# (k, n, sample) = (1, 10, 710)
# (k, n, sample) = (1, 10, 711)
# (k, n, sample) = (1, 10, 712)
# (k, n, sample) = (1, 10, 713)
# (k, n, sample) = (1, 10, 714)
# (k, n, sample) = (1, 10, 715)
# (k, n, sample) = (1, 10, 716)
# (k, n, sample) = (1, 10, 717)
# (k, n, sample) = (1, 10, 718)
# (k, n, sample) = (1, 10, 719)
# (k, n, sample) = (1, 10, 720)
# (k, n, sample) = (1, 10, 721)
# (k, n, sample) = (1, 10, 722)
# (k, n, sample) = (1, 10, 723)
# (k, n, sample) = (1, 10, 724)
# (k, n, sample) = (1, 10, 725)
# (k, n, sample) = (1, 10, 726)
# (k, n, sample) = (1, 10, 727)
# (k, n, sample) = (1, 10, 728)
# (k, n, sample) = (1, 10, 729)
# (k, n, sample) = (1, 10, 730)
# (k, n, sample) = (1, 10, 731)
# (k, n, sample) = (1, 10, 732)
# (k, n, sample) = (1, 10, 733)
# (k, n, sample) = (1, 10, 734)
# (k, n, sample) = (1, 10, 735)
# (k, n, sample) = (1, 10, 736)
# (k, n, sample) = (1, 10, 737)
# (k, n, sample) = (1, 10, 738)
# (k, n, sample) = (1, 10, 739)
# (k, n, sample) = (1, 10, 740)
# (k, n, sample) = (1, 10, 741)
# (k, n, sample) = (1, 10, 742)
# (k, n, sample) = (1, 10, 743)
# (k, n, sample) = (1, 10, 744)
# (k, n, sample) = (1, 10, 745)
# (k, n, sample) = (1, 10, 746)
# (k, n, sample) = (1, 10, 747)
# (k, n, sample) = (1, 10, 748)
# (k, n, sample) = (1, 10, 749)
# (k, n, sample) = (1, 10, 750)
# (k, n, sample) = (1, 10, 751)
# (k, n, sample) = (1, 10, 752)
# (k, n, sample) = (1, 10, 753)
# (k, n, sample) = (1, 10, 754)
# (k, n, sample) = (1, 10, 755)
# (k, n, sample) = (1, 10, 756)
# (k, n, sample) = (1, 10, 757)
# (k, n, sample) = (1, 10, 758)
# (k, n, sample) = (1, 10, 759)
# (k, n, sample) = (1, 10, 760)
# (k, n, sample) = (1, 10, 761)
# (k, n, sample) = (1, 10, 762)
# (k, n, sample) = (1, 10, 763)
# (k, n, sample) = (1, 10, 764)
# (k, n, sample) = (1, 10, 765)
# (k, n, sample) = (1, 10, 766)
# (k, n, sample) = (1, 10, 767)
# (k, n, sample) = (1, 10, 768)
# (k, n, sample) = (1, 10, 769)
# (k, n, sample) = (1, 10, 770)
# (k, n, sample) = (1, 10, 771)
# (k, n, sample) = (1, 10, 772)
# (k, n, sample) = (1, 10, 773)
# (k, n, sample) = (1, 10, 774)
# (k, n, sample) = (1, 10, 775)
# (k, n, sample) = (1, 10, 776)
# (k, n, sample) = (1, 10, 777)
# (k, n, sample) = (1, 10, 778)
# (k, n, sample) = (1, 10, 779)
# (k, n, sample) = (1, 10, 780)
# (k, n, sample) = (1, 10, 781)
# (k, n, sample) = (1, 10, 782)
# (k, n, sample) = (1, 10, 783)
# (k, n, sample) = (1, 10, 784)
# (k, n, sample) = (1, 10, 785)
# (k, n, sample) = (1, 10, 786)
# (k, n, sample) = (1, 10, 787)
# (k, n, sample) = (1, 10, 788)
# (k, n, sample) = (1, 10, 789)
# (k, n, sample) = (1, 10, 790)
# (k, n, sample) = (1, 10, 791)
# (k, n, sample) = (1, 10, 792)
# (k, n, sample) = (1, 10, 793)
# (k, n, sample) = (1, 10, 794)
# (k, n, sample) = (1, 10, 795)
# (k, n, sample) = (1, 10, 796)
# (k, n, sample) = (1, 10, 797)
# (k, n, sample) = (1, 10, 798)
# (k, n, sample) = (1, 10, 799)
# (k, n, sample) = (1, 10, 800)
# (k, n, sample) = (1, 10, 801)
# (k, n, sample) = (1, 10, 802)
# (k, n, sample) = (1, 10, 803)
# (k, n, sample) = (1, 10, 804)
# (k, n, sample) = (1, 10, 805)
# (k, n, sample) = (1, 10, 806)
# (k, n, sample) = (1, 10, 807)
# (k, n, sample) = (1, 10, 808)
# (k, n, sample) = (1, 10, 809)
# (k, n, sample) = (1, 10, 810)
# (k, n, sample) = (1, 10, 811)
# (k, n, sample) = (1, 10, 812)
# (k, n, sample) = (1, 10, 813)
# (k, n, sample) = (1, 10, 814)
# (k, n, sample) = (1, 10, 815)
# (k, n, sample) = (1, 10, 816)
# (k, n, sample) = (1, 10, 817)
# (k, n, sample) = (1, 10, 818)
# (k, n, sample) = (1, 10, 819)
# (k, n, sample) = (1, 10, 820)
# (k, n, sample) = (1, 10, 821)
# (k, n, sample) = (1, 10, 822)
# (k, n, sample) = (1, 10, 823)
# (k, n, sample) = (1, 10, 824)
# (k, n, sample) = (1, 10, 825)
# (k, n, sample) = (1, 10, 826)
# (k, n, sample) = (1, 10, 827)
# (k, n, sample) = (1, 10, 828)
# (k, n, sample) = (1, 10, 829)
# (k, n, sample) = (1, 10, 830)
# (k, n, sample) = (1, 10, 831)
# (k, n, sample) = (1, 10, 832)
# (k, n, sample) = (1, 10, 833)
# (k, n, sample) = (1, 10, 834)
# (k, n, sample) = (1, 10, 835)
# (k, n, sample) = (1, 10, 836)
# (k, n, sample) = (1, 10, 837)
# (k, n, sample) = (1, 10, 838)
# (k, n, sample) = (1, 10, 839)
# (k, n, sample) = (1, 10, 840)
# (k, n, sample) = (1, 10, 841)
# (k, n, sample) = (1, 10, 842)
# (k, n, sample) = (1, 10, 843)
# (k, n, sample) = (1, 10, 844)
# (k, n, sample) = (1, 10, 845)
# (k, n, sample) = (1, 10, 846)
# (k, n, sample) = (1, 10, 847)
# (k, n, sample) = (1, 10, 848)
# (k, n, sample) = (1, 10, 849)
# (k, n, sample) = (1, 10, 850)
# (k, n, sample) = (1, 10, 851)
# (k, n, sample) = (1, 10, 852)
# (k, n, sample) = (1, 10, 853)
# (k, n, sample) = (1, 10, 854)
# (k, n, sample) = (1, 10, 855)
# (k, n, sample) = (1, 10, 856)
# (k, n, sample) = (1, 10, 857)
# (k, n, sample) = (1, 10, 858)
# (k, n, sample) = (1, 10, 859)
# (k, n, sample) = (1, 10, 860)
# (k, n, sample) = (1, 10, 861)
# (k, n, sample) = (1, 10, 862)
# (k, n, sample) = (1, 10, 863)
# (k, n, sample) = (1, 10, 864)
# (k, n, sample) = (1, 10, 865)
# (k, n, sample) = (1, 10, 866)
# (k, n, sample) = (1, 10, 867)
# (k, n, sample) = (1, 10, 868)
# (k, n, sample) = (1, 10, 869)
# (k, n, sample) = (1, 10, 870)
# (k, n, sample) = (1, 10, 871)
# (k, n, sample) = (1, 10, 872)
# (k, n, sample) = (1, 10, 873)
# (k, n, sample) = (1, 10, 874)
# (k, n, sample) = (1, 10, 875)
# (k, n, sample) = (1, 10, 876)
# (k, n, sample) = (1, 10, 877)
# (k, n, sample) = (1, 10, 878)
# (k, n, sample) = (1, 10, 879)
# (k, n, sample) = (1, 10, 880)
# (k, n, sample) = (1, 10, 881)
# (k, n, sample) = (1, 10, 882)
# (k, n, sample) = (1, 10, 883)
# (k, n, sample) = (1, 10, 884)
# (k, n, sample) = (1, 10, 885)
# (k, n, sample) = (1, 10, 886)
# (k, n, sample) = (1, 10, 887)
# (k, n, sample) = (1, 10, 888)
# (k, n, sample) = (1, 10, 889)
# (k, n, sample) = (1, 10, 890)
# (k, n, sample) = (1, 10, 891)
# (k, n, sample) = (1, 10, 892)
# (k, n, sample) = (1, 10, 893)
# (k, n, sample) = (1, 10, 894)
# (k, n, sample) = (1, 10, 895)
# (k, n, sample) = (1, 10, 896)
# (k, n, sample) = (1, 10, 897)
# (k, n, sample) = (1, 10, 898)
# (k, n, sample) = (1, 10, 899)
# (k, n, sample) = (1, 10, 900)
# (k, n, sample) = (1, 10, 901)
# (k, n, sample) = (1, 10, 902)
# (k, n, sample) = (1, 10, 903)
# (k, n, sample) = (1, 10, 904)
# (k, n, sample) = (1, 10, 905)
# (k, n, sample) = (1, 10, 906)
# (k, n, sample) = (1, 10, 907)
# (k, n, sample) = (1, 10, 908)
# (k, n, sample) = (1, 10, 909)
# (k, n, sample) = (1, 10, 910)
# (k, n, sample) = (1, 10, 911)
# (k, n, sample) = (1, 10, 912)
# (k, n, sample) = (1, 10, 913)
# (k, n, sample) = (1, 10, 914)
# (k, n, sample) = (1, 10, 915)
# (k, n, sample) = (1, 10, 916)
# (k, n, sample) = (1, 10, 917)
# (k, n, sample) = (1, 10, 918)
# (k, n, sample) = (1, 10, 919)
# (k, n, sample) = (1, 10, 920)
# (k, n, sample) = (1, 10, 921)
# (k, n, sample) = (1, 10, 922)
# (k, n, sample) = (1, 10, 923)
# (k, n, sample) = (1, 10, 924)
# (k, n, sample) = (1, 10, 925)
# (k, n, sample) = (1, 10, 926)
# (k, n, sample) = (1, 10, 927)
# (k, n, sample) = (1, 10, 928)
# (k, n, sample) = (1, 10, 929)
# (k, n, sample) = (1, 10, 930)
# (k, n, sample) = (1, 10, 931)
# (k, n, sample) = (1, 10, 932)
# (k, n, sample) = (1, 10, 933)
# (k, n, sample) = (1, 10, 934)
# (k, n, sample) = (1, 10, 935)
# (k, n, sample) = (1, 10, 936)
# (k, n, sample) = (1, 10, 937)
# (k, n, sample) = (1, 10, 938)
# (k, n, sample) = (1, 10, 939)
# (k, n, sample) = (1, 10, 940)
# (k, n, sample) = (1, 10, 941)
# (k, n, sample) = (1, 10, 942)
# (k, n, sample) = (1, 10, 943)
# (k, n, sample) = (1, 10, 944)
# (k, n, sample) = (1, 10, 945)
# (k, n, sample) = (1, 10, 946)
# (k, n, sample) = (1, 10, 947)
# (k, n, sample) = (1, 10, 948)
# (k, n, sample) = (1, 10, 949)
# (k, n, sample) = (1, 10, 950)
# (k, n, sample) = (1, 10, 951)
# (k, n, sample) = (1, 10, 952)
# (k, n, sample) = (1, 10, 953)
# (k, n, sample) = (1, 10, 954)
# (k, n, sample) = (1, 10, 955)
# (k, n, sample) = (1, 10, 956)
# (k, n, sample) = (1, 10, 957)
# (k, n, sample) = (1, 10, 958)
# (k, n, sample) = (1, 10, 959)
# (k, n, sample) = (1, 10, 960)
# (k, n, sample) = (1, 10, 961)
# (k, n, sample) = (1, 10, 962)
# (k, n, sample) = (1, 10, 963)
# (k, n, sample) = (1, 10, 964)
# (k, n, sample) = (1, 10, 965)
# (k, n, sample) = (1, 10, 966)
# (k, n, sample) = (1, 10, 967)
# (k, n, sample) = (1, 10, 968)
# (k, n, sample) = (1, 10, 969)
# (k, n, sample) = (1, 10, 970)
# (k, n, sample) = (1, 10, 971)
# (k, n, sample) = (1, 10, 972)
# (k, n, sample) = (1, 10, 973)
# (k, n, sample) = (1, 10, 974)
# (k, n, sample) = (1, 10, 975)
# (k, n, sample) = (1, 10, 976)
# (k, n, sample) = (1, 10, 977)
# (k, n, sample) = (1, 10, 978)
# (k, n, sample) = (1, 10, 979)
# (k, n, sample) = (1, 10, 980)
# (k, n, sample) = (1, 10, 981)
# (k, n, sample) = (1, 10, 982)
# (k, n, sample) = (1, 10, 983)
# (k, n, sample) = (1, 10, 984)
# (k, n, sample) = (1, 10, 985)
# (k, n, sample) = (1, 10, 986)
# (k, n, sample) = (1, 10, 987)
# (k, n, sample) = (1, 10, 988)
# (k, n, sample) = (1, 10, 989)
# (k, n, sample) = (1, 10, 990)
# (k, n, sample) = (1, 10, 991)
# (k, n, sample) = (1, 10, 992)
# (k, n, sample) = (1, 10, 993)
# (k, n, sample) = (1, 10, 994)
# (k, n, sample) = (1, 10, 995)
# (k, n, sample) = (1, 10, 996)
# (k, n, sample) = (1, 10, 997)
# (k, n, sample) = (1, 10, 998)
# (k, n, sample) = (1, 10, 999)
# (k, n, sample) = (1, 10, 1000)
# (k, n, sample) = (1, 10, 1001)
# (k, n, sample) = (1, 10, 1002)
# (k, n, sample) = (1, 10, 1003)
# (k, n, sample) = (1, 10, 1004)
# (k, n, sample) = (1, 10, 1005)
# (k, n, sample) = (1, 10, 1006)
# (k, n, sample) = (1, 10, 1007)
# (k, n, sample) = (1, 10, 1008)
# (k, n, sample) = (1, 10, 1009)
# (k, n, sample) = (1, 10, 1010)
# (k, n, sample) = (1, 10, 1011)
# (k, n, sample) = (1, 10, 1012)
# (k, n, sample) = (1, 10, 1013)
# (k, n, sample) = (1, 10, 1014)
# (k, n, sample) = (1, 10, 1015)
# (k, n, sample) = (1, 10, 1016)
# (k, n, sample) = (1, 10, 1017)
# (k, n, sample) = (1, 10, 1018)
# (k, n, sample) = (1, 10, 1019)
# (k, n, sample) = (1, 10, 1020)
# (k, n, sample) = (1, 10, 1021)
# (k, n, sample) = (1, 10, 1022)
# (k, n, sample) = (1, 10, 1023)
# (k, n, sample) = (1, 10, 1024)
# (k, n, sample) = (1, 10, 1025)
# (k, n, sample) = (1, 10, 1026)
# (k, n, sample) = (1, 10, 1027)
# (k, n, sample) = (1, 10, 1028)
# (k, n, sample) = (1, 10, 1029)
# (k, n, sample) = (1, 10, 1030)
# (k, n, sample) = (1, 10, 1031)
# (k, n, sample) = (1, 10, 1032)
# (k, n, sample) = (1, 10, 1033)
# (k, n, sample) = (1, 10, 1034)
# (k, n, sample) = (1, 10, 1035)
# (k, n, sample) = (1, 10, 1036)
# (k, n, sample) = (1, 10, 1037)
# (k, n, sample) = (1, 10, 1038)
# (k, n, sample) = (1, 10, 1039)
# (k, n, sample) = (1, 10, 1040)
# (k, n, sample) = (1, 10, 1041)
# (k, n, sample) = (1, 10, 1042)
# (k, n, sample) = (1, 10, 1043)
# (k, n, sample) = (1, 10, 1044)
# (k, n, sample) = (1, 10, 1045)
# (k, n, sample) = (1, 10, 1046)
# (k, n, sample) = (1, 10, 1047)
# (k, n, sample) = (1, 10, 1048)
# (k, n, sample) = (1, 10, 1049)
# (k, n, sample) = (1, 10, 1050)
# (k, n, sample) = (1, 10, 1051)
# (k, n, sample) = (1, 10, 1052)
# (k, n, sample) = (1, 10, 1053)
# (k, n, sample) = (1, 10, 1054)
# (k, n, sample) = (1, 10, 1055)
# (k, n, sample) = (1, 10, 1056)
# (k, n, sample) = (1, 10, 1057)
# (k, n, sample) = (1, 10, 1058)
# (k, n, sample) = (1, 10, 1059)
# (k, n, sample) = (1, 10, 1060)
# (k, n, sample) = (1, 10, 1061)
# (k, n, sample) = (1, 10, 1062)
# (k, n, sample) = (1, 10, 1063)
# (k, n, sample) = (1, 10, 1064)
# (k, n, sample) = (1, 10, 1065)
# (k, n, sample) = (1, 10, 1066)
# (k, n, sample) = (1, 10, 1067)
# (k, n, sample) = (1, 10, 1068)
# (k, n, sample) = (1, 10, 1069)
# (k, n, sample) = (1, 10, 1070)
# (k, n, sample) = (1, 10, 1071)
# (k, n, sample) = (1, 10, 1072)
# (k, n, sample) = (1, 10, 1073)
# (k, n, sample) = (1, 10, 1074)
# (k, n, sample) = (1, 10, 1075)
# (k, n, sample) = (1, 10, 1076)
# (k, n, sample) = (1, 10, 1077)
# (k, n, sample) = (1, 10, 1078)
# (k, n, sample) = (1, 10, 1079)
# (k, n, sample) = (1, 10, 1080)
# (k, n, sample) = (1, 10, 1081)
# (k, n, sample) = (1, 10, 1082)
# (k, n, sample) = (1, 10, 1083)
# (k, n, sample) = (1, 10, 1084)
# (k, n, sample) = (1, 10, 1085)
# (k, n, sample) = (1, 10, 1086)
# (k, n, sample) = (1, 10, 1087)
# (k, n, sample) = (1, 10, 1088)
# (k, n, sample) = (1, 10, 1089)
# (k, n, sample) = (1, 10, 1090)
# (k, n, sample) = (1, 10, 1091)
# (k, n, sample) = (1, 10, 1092)
# (k, n, sample) = (1, 10, 1093)
# (k, n, sample) = (1, 10, 1094)
# (k, n, sample) = (1, 10, 1095)
# (k, n, sample) = (1, 10, 1096)
# (k, n, sample) = (1, 10, 1097)
# (k, n, sample) = (1, 10, 1098)
# (k, n, sample) = (1, 10, 1099)
# (k, n, sample) = (1, 10, 1100)
# (k, n, sample) = (1, 10, 1101)
# (k, n, sample) = (1, 10, 1102)
# (k, n, sample) = (1, 10, 1103)
# (k, n, sample) = (1, 10, 1104)
# (k, n, sample) = (1, 10, 1105)
# (k, n, sample) = (1, 10, 1106)
# (k, n, sample) = (1, 10, 1107)
# (k, n, sample) = (1, 10, 1108)
# (k, n, sample) = (1, 10, 1109)
# (k, n, sample) = (1, 10, 1110)
# (k, n, sample) = (1, 10, 1111)
# (k, n, sample) = (1, 10, 1112)
# (k, n, sample) = (1, 10, 1113)
# (k, n, sample) = (1, 10, 1114)
# (k, n, sample) = (1, 10, 1115)
# (k, n, sample) = (1, 10, 1116)
# (k, n, sample) = (1, 10, 1117)
# (k, n, sample) = (1, 10, 1118)
# (k, n, sample) = (1, 10, 1119)
# (k, n, sample) = (1, 10, 1120)
# (k, n, sample) = (1, 10, 1121)
# (k, n, sample) = (1, 10, 1122)
# (k, n, sample) = (1, 10, 1123)
# (k, n, sample) = (1, 10, 1124)
# (k, n, sample) = (1, 10, 1125)
# (k, n, sample) = (1, 10, 1126)
# (k, n, sample) = (1, 10, 1127)
# (k, n, sample) = (1, 10, 1128)
# (k, n, sample) = (1, 10, 1129)
# (k, n, sample) = (1, 10, 1130)
# (k, n, sample) = (1, 10, 1131)
# (k, n, sample) = (1, 10, 1132)
# (k, n, sample) = (1, 10, 1133)
# (k, n, sample) = (1, 10, 1134)
# (k, n, sample) = (1, 10, 1135)
# (k, n, sample) = (1, 10, 1136)
# (k, n, sample) = (1, 10, 1137)
# (k, n, sample) = (1, 10, 1138)
# (k, n, sample) = (1, 10, 1139)
# (k, n, sample) = (1, 10, 1140)
# (k, n, sample) = (1, 10, 1141)
# (k, n, sample) = (1, 10, 1142)
# (k, n, sample) = (1, 10, 1143)
# (k, n, sample) = (1, 10, 1144)
# (k, n, sample) = (1, 10, 1145)
# (k, n, sample) = (1, 10, 1146)
# (k, n, sample) = (1, 10, 1147)
# (k, n, sample) = (1, 10, 1148)
# (k, n, sample) = (1, 10, 1149)
# (k, n, sample) = (1, 10, 1150)
# (k, n, sample) = (1, 10, 1151)
# (k, n, sample) = (1, 10, 1152)
# (k, n, sample) = (1, 10, 1153)
# (k, n, sample) = (1, 10, 1154)
# (k, n, sample) = (1, 10, 1155)
# (k, n, sample) = (1, 10, 1156)
# (k, n, sample) = (1, 10, 1157)
# (k, n, sample) = (1, 10, 1158)
# (k, n, sample) = (1, 10, 1159)
# (k, n, sample) = (1, 10, 1160)
# (k, n, sample) = (1, 10, 1161)
# (k, n, sample) = (1, 10, 1162)
# (k, n, sample) = (1, 10, 1163)
# (k, n, sample) = (1, 10, 1164)
# (k, n, sample) = (1, 10, 1165)
# (k, n, sample) = (1, 10, 1166)
# (k, n, sample) = (1, 10, 1167)
# (k, n, sample) = (1, 10, 1168)
# (k, n, sample) = (1, 10, 1169)
# (k, n, sample) = (1, 10, 1170)
# (k, n, sample) = (1, 10, 1171)
# (k, n, sample) = (1, 10, 1172)
# (k, n, sample) = (1, 10, 1173)
# (k, n, sample) = (1, 10, 1174)
# (k, n, sample) = (1, 10, 1175)
# (k, n, sample) = (1, 10, 1176)
# (k, n, sample) = (1, 10, 1177)
# (k, n, sample) = (1, 10, 1178)
# (k, n, sample) = (1, 10, 1179)
# (k, n, sample) = (1, 10, 1180)
# (k, n, sample) = (1, 10, 1181)
# (k, n, sample) = (1, 10, 1182)
# (k, n, sample) = (1, 10, 1183)
# (k, n, sample) = (1, 10, 1184)
# (k, n, sample) = (1, 10, 1185)
# (k, n, sample) = (1, 10, 1186)
# (k, n, sample) = (1, 10, 1187)
# (k, n, sample) = (1, 10, 1188)
# (k, n, sample) = (1, 10, 1189)
# (k, n, sample) = (1, 10, 1190)
# (k, n, sample) = (1, 10, 1191)
# (k, n, sample) = (1, 10, 1192)
# (k, n, sample) = (1, 10, 1193)
# (k, n, sample) = (1, 10, 1194)
# (k, n, sample) = (1, 10, 1195)
# (k, n, sample) = (1, 10, 1196)
# (k, n, sample) = (1, 10, 1197)
# (k, n, sample) = (1, 10, 1198)
# (k, n, sample) = (1, 10, 1199)
# (k, n, sample) = (1, 10, 1200)
# (k, n, sample) = (1, 10, 1201)
# (k, n, sample) = (1, 10, 1202)
# (k, n, sample) = (1, 10, 1203)
# (k, n, sample) = (1, 10, 1204)
# (k, n, sample) = (1, 10, 1205)
# (k, n, sample) = (1, 10, 1206)
# (k, n, sample) = (1, 10, 1207)
# (k, n, sample) = (1, 10, 1208)
# (k, n, sample) = (1, 10, 1209)
# (k, n, sample) = (1, 10, 1210)
# (k, n, sample) = (1, 10, 1211)
# (k, n, sample) = (1, 10, 1212)
# (k, n, sample) = (1, 10, 1213)
# (k, n, sample) = (1, 10, 1214)
# (k, n, sample) = (1, 10, 1215)
# (k, n, sample) = (1, 10, 1216)
# (k, n, sample) = (1, 10, 1217)
# (k, n, sample) = (1, 10, 1218)
# (k, n, sample) = (1, 10, 1219)
# (k, n, sample) = (1, 10, 1220)
# (k, n, sample) = (1, 10, 1221)
# (k, n, sample) = (1, 10, 1222)
# (k, n, sample) = (1, 10, 1223)
# (k, n, sample) = (1, 10, 1224)
# (k, n, sample) = (1, 10, 1225)
# (k, n, sample) = (1, 10, 1226)
# (k, n, sample) = (1, 10, 1227)
# (k, n, sample) = (1, 10, 1228)
# (k, n, sample) = (1, 10, 1229)
# (k, n, sample) = (1, 10, 1230)
# (k, n, sample) = (1, 10, 1231)
# (k, n, sample) = (1, 10, 1232)
# (k, n, sample) = (1, 10, 1233)
# (k, n, sample) = (1, 10, 1234)
# (k, n, sample) = (1, 10, 1235)
# (k, n, sample) = (1, 10, 1236)
# (k, n, sample) = (1, 10, 1237)
# (k, n, sample) = (1, 10, 1238)
# (k, n, sample) = (1, 10, 1239)
# (k, n, sample) = (1, 10, 1240)
# (k, n, sample) = (1, 10, 1241)
# (k, n, sample) = (1, 10, 1242)
# (k, n, sample) = (1, 10, 1243)
# (k, n, sample) = (1, 10, 1244)
# (k, n, sample) = (1, 10, 1245)
# (k, n, sample) = (1, 10, 1246)
# (k, n, sample) = (1, 10, 1247)
# (k, n, sample) = (1, 10, 1248)
# (k, n, sample) = (1, 10, 1249)
# (k, n, sample) = (1, 10, 1250)
# (k, n, sample) = (1, 10, 1251)
# (k, n, sample) = (1, 10, 1252)
# (k, n, sample) = (1, 10, 1253)
# (k, n, sample) = (1, 10, 1254)
# (k, n, sample) = (1, 10, 1255)
# (k, n, sample) = (1, 10, 1256)
# (k, n, sample) = (1, 10, 1257)
# (k, n, sample) = (1, 10, 1258)
# (k, n, sample) = (1, 10, 1259)
# (k, n, sample) = (1, 10, 1260)
# (k, n, sample) = (1, 10, 1261)
# (k, n, sample) = (1, 10, 1262)
# (k, n, sample) = (1, 10, 1263)
# (k, n, sample) = (1, 10, 1264)
# (k, n, sample) = (1, 10, 1265)
# (k, n, sample) = (1, 10, 1266)
# (k, n, sample) = (1, 10, 1267)
# (k, n, sample) = (1, 10, 1268)
# (k, n, sample) = (1, 10, 1269)
# (k, n, sample) = (1, 10, 1270)
# (k, n, sample) = (1, 10, 1271)
# (k, n, sample) = (1, 10, 1272)
# (k, n, sample) = (1, 10, 1273)
# (k, n, sample) = (1, 10, 1274)
# (k, n, sample) = (1, 10, 1275)
# (k, n, sample) = (1, 10, 1276)
# (k, n, sample) = (1, 10, 1277)
# (k, n, sample) = (1, 10, 1278)
# (k, n, sample) = (1, 10, 1279)
# (k, n, sample) = (1, 10, 1280)
# (k, n, sample) = (1, 10, 1281)
# (k, n, sample) = (1, 10, 1282)
# (k, n, sample) = (1, 10, 1283)
# (k, n, sample) = (1, 10, 1284)
# (k, n, sample) = (1, 10, 1285)
# (k, n, sample) = (1, 10, 1286)
# (k, n, sample) = (1, 10, 1287)
# (k, n, sample) = (1, 10, 1288)
# (k, n, sample) = (1, 10, 1289)
# (k, n, sample) = (1, 10, 1290)
# (k, n, sample) = (1, 10, 1291)
# (k, n, sample) = (1, 10, 1292)
# (k, n, sample) = (1, 10, 1293)
# (k, n, sample) = (1, 10, 1294)
# (k, n, sample) = (1, 10, 1295)
# (k, n, sample) = (1, 10, 1296)
# (k, n, sample) = (1, 10, 1297)
# (k, n, sample) = (1, 10, 1298)
# (k, n, sample) = (1, 10, 1299)
# (k, n, sample) = (1, 10, 1300)
# (k, n, sample) = (1, 10, 1301)
# (k, n, sample) = (1, 10, 1302)
# (k, n, sample) = (1, 10, 1303)
# (k, n, sample) = (1, 10, 1304)
# (k, n, sample) = (1, 10, 1305)
# (k, n, sample) = (1, 10, 1306)
# (k, n, sample) = (1, 10, 1307)
# (k, n, sample) = (1, 10, 1308)
# (k, n, sample) = (1, 10, 1309)
# (k, n, sample) = (1, 10, 1310)
# (k, n, sample) = (1, 10, 1311)
# (k, n, sample) = (1, 10, 1312)
# (k, n, sample) = (1, 10, 1313)
# (k, n, sample) = (1, 10, 1314)
# (k, n, sample) = (1, 10, 1315)
# (k, n, sample) = (1, 10, 1316)
# (k, n, sample) = (1, 10, 1317)
# (k, n, sample) = (1, 10, 1318)
# (k, n, sample) = (1, 10, 1319)
# (k, n, sample) = (1, 10, 1320)
# (k, n, sample) = (1, 10, 1321)
# (k, n, sample) = (1, 10, 1322)
# (k, n, sample) = (1, 10, 1323)
# (k, n, sample) = (1, 10, 1324)
# (k, n, sample) = (1, 10, 1325)
# (k, n, sample) = (1, 10, 1326)
# (k, n, sample) = (1, 10, 1327)
# (k, n, sample) = (1, 10, 1328)
# (k, n, sample) = (1, 10, 1329)
# (k, n, sample) = (1, 10, 1330)
# (k, n, sample) = (1, 10, 1331)
# (k, n, sample) = (1, 10, 1332)
# (k, n, sample) = (1, 10, 1333)
# (k, n, sample) = (1, 10, 1334)
# (k, n, sample) = (1, 10, 1335)
# (k, n, sample) = (1, 10, 1336)
# (k, n, sample) = (1, 10, 1337)
# (k, n, sample) = (1, 10, 1338)
# (k, n, sample) = (1, 10, 1339)
# (k, n, sample) = (1, 10, 1340)
# (k, n, sample) = (1, 10, 1341)
# (k, n, sample) = (1, 10, 1342)
# (k, n, sample) = (1, 10, 1343)
# (k, n, sample) = (1, 10, 1344)
# (k, n, sample) = (1, 10, 1345)
# (k, n, sample) = (1, 10, 1346)
# (k, n, sample) = (1, 10, 1347)
# (k, n, sample) = (1, 10, 1348)
# (k, n, sample) = (1, 10, 1349)
# (k, n, sample) = (1, 10, 1350)
# (k, n, sample) = (1, 10, 1351)
# (k, n, sample) = (1, 10, 1352)
# (k, n, sample) = (1, 10, 1353)
# (k, n, sample) = (1, 10, 1354)
# (k, n, sample) = (1, 10, 1355)
# (k, n, sample) = (1, 10, 1356)
# (k, n, sample) = (1, 10, 1357)
# (k, n, sample) = (1, 10, 1358)
# (k, n, sample) = (1, 10, 1359)
# (k, n, sample) = (1, 10, 1360)
# (k, n, sample) = (1, 10, 1361)
# (k, n, sample) = (1, 10, 1362)
# (k, n, sample) = (1, 10, 1363)
# (k, n, sample) = (1, 10, 1364)
# (k, n, sample) = (1, 10, 1365)
# (k, n, sample) = (1, 10, 1366)
# (k, n, sample) = (1, 10, 1367)
# (k, n, sample) = (1, 10, 1368)
# (k, n, sample) = (1, 10, 1369)
# (k, n, sample) = (1, 10, 1370)
# (k, n, sample) = (1, 10, 1371)
# (k, n, sample) = (1, 10, 1372)
# (k, n, sample) = (1, 10, 1373)
# (k, n, sample) = (1, 10, 1374)
# (k, n, sample) = (1, 10, 1375)
# (k, n, sample) = (1, 10, 1376)
# (k, n, sample) = (1, 10, 1377)
# (k, n, sample) = (1, 10, 1378)
# (k, n, sample) = (1, 10, 1379)
# (k, n, sample) = (1, 10, 1380)
# (k, n, sample) = (1, 10, 1381)
# (k, n, sample) = (1, 10, 1382)
# (k, n, sample) = (1, 10, 1383)
# (k, n, sample) = (1, 10, 1384)
# (k, n, sample) = (1, 10, 1385)
# (k, n, sample) = (1, 10, 1386)
# (k, n, sample) = (1, 10, 1387)
# (k, n, sample) = (1, 10, 1388)
# (k, n, sample) = (1, 10, 1389)
# (k, n, sample) = (1, 10, 1390)
# (k, n, sample) = (1, 10, 1391)
# (k, n, sample) = (1, 10, 1392)
# (k, n, sample) = (1, 10, 1393)
# (k, n, sample) = (1, 10, 1394)
# (k, n, sample) = (1, 10, 1395)
# (k, n, sample) = (1, 10, 1396)
# (k, n, sample) = (1, 10, 1397)
# (k, n, sample) = (1, 10, 1398)
# (k, n, sample) = (1, 10, 1399)
# (k, n, sample) = (1, 10, 1400)
# (k, n, sample) = (1, 10, 1401)
# (k, n, sample) = (1, 10, 1402)
# (k, n, sample) = (1, 10, 1403)
# (k, n, sample) = (1, 10, 1404)
# (k, n, sample) = (1, 10, 1405)
# (k, n, sample) = (1, 10, 1406)
# (k, n, sample) = (1, 10, 1407)
# (k, n, sample) = (1, 10, 1408)
# (k, n, sample) = (1, 10, 1409)
# (k, n, sample) = (1, 10, 1410)
# (k, n, sample) = (1, 10, 1411)
# (k, n, sample) = (1, 10, 1412)
# (k, n, sample) = (1, 10, 1413)
# (k, n, sample) = (1, 10, 1414)
# (k, n, sample) = (1, 10, 1415)
# (k, n, sample) = (1, 10, 1416)
# (k, n, sample) = (1, 10, 1417)
# (k, n, sample) = (1, 10, 1418)
# (k, n, sample) = (1, 10, 1419)
# (k, n, sample) = (1, 10, 1420)
# (k, n, sample) = (1, 10, 1421)
# (k, n, sample) = (1, 10, 1422)
# (k, n, sample) = (1, 10, 1423)
# (k, n, sample) = (1, 10, 1424)
# (k, n, sample) = (1, 10, 1425)
# (k, n, sample) = (1, 10, 1426)
# (k, n, sample) = (1, 10, 1427)
# (k, n, sample) = (1, 10, 1428)
# (k, n, sample) = (1, 10, 1429)
# (k, n, sample) = (1, 10, 1430)
# (k, n, sample) = (1, 10, 1431)
# (k, n, sample) = (1, 10, 1432)
# (k, n, sample) = (1, 10, 1433)
# (k, n, sample) = (1, 10, 1434)
# (k, n, sample) = (1, 10, 1435)
# (k, n, sample) = (1, 10, 1436)
# (k, n, sample) = (1, 10, 1437)
# (k, n, sample) = (1, 10, 1438)
# (k, n, sample) = (1, 10, 1439)
# (k, n, sample) = (1, 10, 1440)
# (k, n, sample) = (1, 10, 1441)
# (k, n, sample) = (1, 10, 1442)
# (k, n, sample) = (1, 10, 1443)
# (k, n, sample) = (1, 10, 1444)
# (k, n, sample) = (1, 10, 1445)
# (k, n, sample) = (1, 10, 1446)
# (k, n, sample) = (1, 10, 1447)
# (k, n, sample) = (1, 10, 1448)
# (k, n, sample) = (1, 10, 1449)
# (k, n, sample) = (1, 10, 1450)
# (k, n, sample) = (1, 10, 1451)
# (k, n, sample) = (1, 10, 1452)
# (k, n, sample) = (1, 10, 1453)
# (k, n, sample) = (1, 10, 1454)
# (k, n, sample) = (1, 10, 1455)
# (k, n, sample) = (1, 10, 1456)
# (k, n, sample) = (1, 10, 1457)
# (k, n, sample) = (1, 10, 1458)
# (k, n, sample) = (1, 10, 1459)
# (k, n, sample) = (1, 10, 1460)
# (k, n, sample) = (1, 10, 1461)
# (k, n, sample) = (1, 10, 1462)
# (k, n, sample) = (1, 10, 1463)
# (k, n, sample) = (1, 10, 1464)
# (k, n, sample) = (1, 10, 1465)
# (k, n, sample) = (1, 10, 1466)
# (k, n, sample) = (1, 10, 1467)
# (k, n, sample) = (1, 10, 1468)
# (k, n, sample) = (1, 10, 1469)
# (k, n, sample) = (1, 10, 1470)
# (k, n, sample) = (1, 10, 1471)
# (k, n, sample) = (1, 10, 1472)
# (k, n, sample) = (1, 10, 1473)
# (k, n, sample) = (1, 10, 1474)
# (k, n, sample) = (1, 10, 1475)
# (k, n, sample) = (1, 10, 1476)
# (k, n, sample) = (1, 10, 1477)
# (k, n, sample) = (1, 10, 1478)
# (k, n, sample) = (1, 10, 1479)
# (k, n, sample) = (1, 10, 1480)
# (k, n, sample) = (1, 10, 1481)
# (k, n, sample) = (1, 10, 1482)
# (k, n, sample) = (1, 10, 1483)
# (k, n, sample) = (1, 10, 1484)
# (k, n, sample) = (1, 10, 1485)
# (k, n, sample) = (1, 10, 1486)
# (k, n, sample) = (1, 10, 1487)
# (k, n, sample) = (1, 10, 1488)
# (k, n, sample) = (1, 10, 1489)
# (k, n, sample) = (1, 10, 1490)
# (k, n, sample) = (1, 10, 1491)
# (k, n, sample) = (1, 10, 1492)
# (k, n, sample) = (1, 10, 1493)
# (k, n, sample) = (1, 10, 1494)
# (k, n, sample) = (1, 10, 1495)
# (k, n, sample) = (1, 10, 1496)
# (k, n, sample) = (1, 10, 1497)
# (k, n, sample) = (1, 10, 1498)
# (k, n, sample) = (1, 10, 1499)
# (k, n, sample) = (1, 10, 1500)
# (k, n, sample) = (1, 10, 1501)
# (k, n, sample) = (1, 10, 1502)
# (k, n, sample) = (1, 10, 1503)
# (k, n, sample) = (1, 10, 1504)
# (k, n, sample) = (1, 10, 1505)
# (k, n, sample) = (1, 10, 1506)
# (k, n, sample) = (1, 10, 1507)
# (k, n, sample) = (1, 10, 1508)
# (k, n, sample) = (1, 10, 1509)
# (k, n, sample) = (1, 10, 1510)
# (k, n, sample) = (1, 10, 1511)
# (k, n, sample) = (1, 10, 1512)
# (k, n, sample) = (1, 10, 1513)
# (k, n, sample) = (1, 10, 1514)
# (k, n, sample) = (1, 10, 1515)
# (k, n, sample) = (1, 10, 1516)
# (k, n, sample) = (1, 10, 1517)
# (k, n, sample) = (1, 10, 1518)
# (k, n, sample) = (1, 10, 1519)
# (k, n, sample) = (1, 10, 1520)
# (k, n, sample) = (1, 10, 1521)
# (k, n, sample) = (1, 10, 1522)
# (k, n, sample) = (1, 10, 1523)
# (k, n, sample) = (1, 10, 1524)
# (k, n, sample) = (1, 10, 1525)
# (k, n, sample) = (1, 10, 1526)
# (k, n, sample) = (1, 10, 1527)
# (k, n, sample) = (1, 10, 1528)
# (k, n, sample) = (1, 10, 1529)
# (k, n, sample) = (1, 10, 1530)
# (k, n, sample) = (1, 10, 1531)
# (k, n, sample) = (1, 10, 1532)
# (k, n, sample) = (1, 10, 1533)
# (k, n, sample) = (1, 10, 1534)
# (k, n, sample) = (1, 10, 1535)
# (k, n, sample) = (1, 10, 1536)
# (k, n, sample) = (1, 10, 1537)
# (k, n, sample) = (1, 10, 1538)
# (k, n, sample) = (1, 10, 1539)
# (k, n, sample) = (1, 10, 1540)
# (k, n, sample) = (1, 10, 1541)
# (k, n, sample) = (1, 10, 1542)
# (k, n, sample) = (1, 10, 1543)
# (k, n, sample) = (1, 10, 1544)
# (k, n, sample) = (1, 10, 1545)
# (k, n, sample) = (1, 10, 1546)
# (k, n, sample) = (1, 10, 1547)
# (k, n, sample) = (1, 10, 1548)
# (k, n, sample) = (1, 10, 1549)
# (k, n, sample) = (1, 10, 1550)
# (k, n, sample) = (1, 10, 1551)
# (k, n, sample) = (1, 10, 1552)
# (k, n, sample) = (1, 10, 1553)
# (k, n, sample) = (1, 10, 1554)
# (k, n, sample) = (1, 10, 1555)
# (k, n, sample) = (1, 10, 1556)
# (k, n, sample) = (1, 10, 1557)
# (k, n, sample) = (1, 10, 1558)
# (k, n, sample) = (1, 10, 1559)
# (k, n, sample) = (1, 10, 1560)
# (k, n, sample) = (1, 10, 1561)
# (k, n, sample) = (1, 10, 1562)
# (k, n, sample) = (1, 10, 1563)
# (k, n, sample) = (1, 10, 1564)
# (k, n, sample) = (1, 10, 1565)
# (k, n, sample) = (1, 10, 1566)
# (k, n, sample) = (1, 10, 1567)
# (k, n, sample) = (1, 10, 1568)
# (k, n, sample) = (1, 10, 1569)
# (k, n, sample) = (1, 10, 1570)
# (k, n, sample) = (1, 10, 1571)
# (k, n, sample) = (1, 10, 1572)
# (k, n, sample) = (1, 10, 1573)
# (k, n, sample) = (1, 10, 1574)
# (k, n, sample) = (1, 10, 1575)
# (k, n, sample) = (1, 10, 1576)
# (k, n, sample) = (1, 10, 1577)
# (k, n, sample) = (1, 10, 1578)
# (k, n, sample) = (1, 10, 1579)
# ...
# (k, n, sample) = (2, 30, 2447)
# (k, n, sample) = (2, 30, 2448)
# (k, n, sample) = (2, 30, 2449)
# (k, n, sample) = (2, 30, 2450)
# (k, n, sample) = (2, 30, 2451)
# (k, n, sample) = (2, 30, 2452)
# (k, n, sample) = (2, 30, 2453)
# (k, n, sample) = (2, 30, 2454)
# (k, n, sample) = (2, 30, 2455)
# (k, n, sample) = (2, 30, 2456)
# (k, n, sample) = (2, 30, 2457)
# (k, n, sample) = (2, 30, 2458)
# (k, n, sample) = (2, 30, 2459)
# (k, n, sample) = (2, 30, 2460)
# (k, n, sample) = (2, 30, 2461)
# (k, n, sample) = (2, 30, 2462)
# (k, n, sample) = (2, 30, 2463)
# (k, n, sample) = (2, 30, 2464)
# (k, n, sample) = (2, 30, 2465)
# (k, n, sample) = (2, 30, 2466)
# (k, n, sample) = (2, 30, 2467)
# (k, n, sample) = (2, 30, 2468)
# (k, n, sample) = (2, 30, 2469)
# (k, n, sample) = (2, 30, 2470)
# (k, n, sample) = (2, 30, 2471)
# (k, n, sample) = (2, 30, 2472)
# (k, n, sample) = (2, 30, 2473)
# (k, n, sample) = (2, 30, 2474)
# (k, n, sample) = (2, 30, 2475)
# (k, n, sample) = (2, 30, 2476)
# (k, n, sample) = (2, 30, 2477)
# (k, n, sample) = (2, 30, 2478)
# (k, n, sample) = (2, 30, 2479)
# (k, n, sample) = (2, 30, 2480)
# (k, n, sample) = (2, 30, 2481)
# (k, n, sample) = (2, 30, 2482)
# (k, n, sample) = (2, 30, 2483)
# (k, n, sample) = (2, 30, 2484)
# (k, n, sample) = (2, 30, 2485)
# (k, n, sample) = (2, 30, 2486)
# (k, n, sample) = (2, 30, 2487)
# (k, n, sample) = (2, 30, 2488)
# (k, n, sample) = (2, 30, 2489)
# (k, n, sample) = (2, 30, 2490)
# (k, n, sample) = (2, 30, 2491)
# (k, n, sample) = (2, 30, 2492)
# (k, n, sample) = (2, 30, 2493)
# (k, n, sample) = (2, 30, 2494)
# (k, n, sample) = (2, 30, 2495)
# (k, n, sample) = (2, 30, 2496)
# (k, n, sample) = (2, 30, 2497)
# (k, n, sample) = (2, 30, 2498)
# (k, n, sample) = (2, 30, 2499)
# (k, n, sample) = (2, 30, 2500)
# (k, n, sample) = (2, 30, 2501)
# (k, n, sample) = (2, 30, 2502)
# (k, n, sample) = (2, 30, 2503)
# (k, n, sample) = (2, 30, 2504)
# (k, n, sample) = (2, 30, 2505)
# (k, n, sample) = (2, 30, 2506)
# (k, n, sample) = (2, 30, 2507)
# (k, n, sample) = (2, 30, 2508)
# (k, n, sample) = (2, 30, 2509)
# (k, n, sample) = (2, 30, 2510)
# (k, n, sample) = (2, 30, 2511)
# (k, n, sample) = (2, 30, 2512)
# (k, n, sample) = (2, 30, 2513)
# (k, n, sample) = (2, 30, 2514)
# (k, n, sample) = (2, 30, 2515)
# (k, n, sample) = (2, 30, 2516)
# (k, n, sample) = (2, 30, 2517)
# (k, n, sample) = (2, 30, 2518)
# (k, n, sample) = (2, 30, 2519)
# (k, n, sample) = (2, 30, 2520)
# (k, n, sample) = (2, 30, 2521)
# (k, n, sample) = (2, 30, 2522)
# (k, n, sample) = (2, 30, 2523)
# (k, n, sample) = (2, 30, 2524)
# (k, n, sample) = (2, 30, 2525)
# (k, n, sample) = (2, 30, 2526)
# (k, n, sample) = (2, 30, 2527)
# (k, n, sample) = (2, 30, 2528)
# (k, n, sample) = (2, 30, 2529)
# (k, n, sample) = (2, 30, 2530)
# (k, n, sample) = (2, 30, 2531)
# (k, n, sample) = (2, 30, 2532)
# (k, n, sample) = (2, 30, 2533)
# (k, n, sample) = (2, 30, 2534)
# (k, n, sample) = (2, 30, 2535)
# (k, n, sample) = (2, 30, 2536)
# (k, n, sample) = (2, 30, 2537)
# (k, n, sample) = (2, 30, 2538)
# (k, n, sample) = (2, 30, 2539)
# (k, n, sample) = (2, 30, 2540)
# (k, n, sample) = (2, 30, 2541)
# (k, n, sample) = (2, 30, 2542)
# (k, n, sample) = (2, 30, 2543)
# (k, n, sample) = (2, 30, 2544)
# (k, n, sample) = (2, 30, 2545)
# (k, n, sample) = (2, 30, 2546)
# (k, n, sample) = (2, 30, 2547)
# (k, n, sample) = (2, 30, 2548)
# (k, n, sample) = (2, 30, 2549)
# (k, n, sample) = (2, 30, 2550)
# (k, n, sample) = (2, 30, 2551)
# (k, n, sample) = (2, 30, 2552)
# (k, n, sample) = (2, 30, 2553)
# (k, n, sample) = (2, 30, 2554)
# (k, n, sample) = (2, 30, 2555)
# (k, n, sample) = (2, 30, 2556)
# (k, n, sample) = (2, 30, 2557)
# (k, n, sample) = (2, 30, 2558)
# (k, n, sample) = (2, 30, 2559)
# (k, n, sample) = (2, 30, 2560)
# (k, n, sample) = (2, 30, 2561)
# (k, n, sample) = (2, 30, 2562)
# (k, n, sample) = (2, 30, 2563)
# (k, n, sample) = (2, 30, 2564)
# (k, n, sample) = (2, 30, 2565)
# (k, n, sample) = (2, 30, 2566)
# (k, n, sample) = (2, 30, 2567)
# (k, n, sample) = (2, 30, 2568)
# (k, n, sample) = (2, 30, 2569)
# (k, n, sample) = (2, 30, 2570)
# (k, n, sample) = (2, 30, 2571)
# (k, n, sample) = (2, 30, 2572)
# (k, n, sample) = (2, 30, 2573)
# (k, n, sample) = (2, 30, 2574)
# (k, n, sample) = (2, 30, 2575)
# (k, n, sample) = (2, 30, 2576)
# (k, n, sample) = (2, 30, 2577)
# (k, n, sample) = (2, 30, 2578)
# (k, n, sample) = (2, 30, 2579)
# (k, n, sample) = (2, 30, 2580)
# (k, n, sample) = (2, 30, 2581)
# (k, n, sample) = (2, 30, 2582)
# (k, n, sample) = (2, 30, 2583)
# (k, n, sample) = (2, 30, 2584)
# (k, n, sample) = (2, 30, 2585)
# (k, n, sample) = (2, 30, 2586)
# (k, n, sample) = (2, 30, 2587)
# (k, n, sample) = (2, 30, 2588)
# (k, n, sample) = (2, 30, 2589)
# (k, n, sample) = (2, 30, 2590)
# (k, n, sample) = (2, 30, 2591)
# (k, n, sample) = (2, 30, 2592)
# (k, n, sample) = (2, 30, 2593)
# (k, n, sample) = (2, 30, 2594)
# (k, n, sample) = (2, 30, 2595)
# (k, n, sample) = (2, 30, 2596)
# (k, n, sample) = (2, 30, 2597)
# (k, n, sample) = (2, 30, 2598)
# (k, n, sample) = (2, 30, 2599)
# (k, n, sample) = (2, 30, 2600)
# (k, n, sample) = (2, 30, 2601)
# (k, n, sample) = (2, 30, 2602)
# (k, n, sample) = (2, 30, 2603)
# (k, n, sample) = (2, 30, 2604)
# (k, n, sample) = (2, 30, 2605)
# (k, n, sample) = (2, 30, 2606)
# (k, n, sample) = (2, 30, 2607)
# (k, n, sample) = (2, 30, 2608)
# (k, n, sample) = (2, 30, 2609)
# (k, n, sample) = (2, 30, 2610)
# (k, n, sample) = (2, 30, 2611)
# (k, n, sample) = (2, 30, 2612)
# (k, n, sample) = (2, 30, 2613)
# (k, n, sample) = (2, 30, 2614)
# (k, n, sample) = (2, 30, 2615)
# (k, n, sample) = (2, 30, 2616)
# (k, n, sample) = (2, 30, 2617)
# (k, n, sample) = (2, 30, 2618)
# (k, n, sample) = (2, 30, 2619)
# (k, n, sample) = (2, 30, 2620)
# (k, n, sample) = (2, 30, 2621)
# (k, n, sample) = (2, 30, 2622)
# (k, n, sample) = (2, 30, 2623)
# (k, n, sample) = (2, 30, 2624)
# (k, n, sample) = (2, 30, 2625)
# (k, n, sample) = (2, 30, 2626)
# (k, n, sample) = (2, 30, 2627)
# (k, n, sample) = (2, 30, 2628)
# (k, n, sample) = (2, 30, 2629)
# (k, n, sample) = (2, 30, 2630)
# (k, n, sample) = (2, 30, 2631)
# (k, n, sample) = (2, 30, 2632)
# (k, n, sample) = (2, 30, 2633)
# (k, n, sample) = (2, 30, 2634)
# (k, n, sample) = (2, 30, 2635)
# (k, n, sample) = (2, 30, 2636)
# (k, n, sample) = (2, 30, 2637)
# (k, n, sample) = (2, 30, 2638)
# (k, n, sample) = (2, 30, 2639)
# (k, n, sample) = (2, 30, 2640)
# (k, n, sample) = (2, 30, 2641)
# (k, n, sample) = (2, 30, 2642)
# (k, n, sample) = (2, 30, 2643)
# (k, n, sample) = (2, 30, 2644)
# (k, n, sample) = (2, 30, 2645)
# (k, n, sample) = (2, 30, 2646)
# (k, n, sample) = (2, 30, 2647)
# (k, n, sample) = (2, 30, 2648)
# (k, n, sample) = (2, 30, 2649)
# (k, n, sample) = (2, 30, 2650)
# (k, n, sample) = (2, 30, 2651)
# (k, n, sample) = (2, 30, 2652)
# (k, n, sample) = (2, 30, 2653)
# (k, n, sample) = (2, 30, 2654)
# (k, n, sample) = (2, 30, 2655)
# (k, n, sample) = (2, 30, 2656)
# (k, n, sample) = (2, 30, 2657)
# (k, n, sample) = (2, 30, 2658)
# (k, n, sample) = (2, 30, 2659)
# (k, n, sample) = (2, 30, 2660)
# (k, n, sample) = (2, 30, 2661)
# (k, n, sample) = (2, 30, 2662)
# (k, n, sample) = (2, 30, 2663)
# (k, n, sample) = (2, 30, 2664)
# (k, n, sample) = (2, 30, 2665)
# (k, n, sample) = (2, 30, 2666)
# (k, n, sample) = (2, 30, 2667)
# (k, n, sample) = (2, 30, 2668)
# (k, n, sample) = (2, 30, 2669)
# (k, n, sample) = (2, 30, 2670)
# (k, n, sample) = (2, 30, 2671)
# (k, n, sample) = (2, 30, 2672)
# (k, n, sample) = (2, 30, 2673)
# (k, n, sample) = (2, 30, 2674)
# (k, n, sample) = (2, 30, 2675)
# (k, n, sample) = (2, 30, 2676)
# (k, n, sample) = (2, 30, 2677)
# (k, n, sample) = (2, 30, 2678)
# (k, n, sample) = (2, 30, 2679)
# (k, n, sample) = (2, 30, 2680)
# (k, n, sample) = (2, 30, 2681)
# (k, n, sample) = (2, 30, 2682)
# (k, n, sample) = (2, 30, 2683)
# (k, n, sample) = (2, 30, 2684)
# (k, n, sample) = (2, 30, 2685)
# (k, n, sample) = (2, 30, 2686)
# (k, n, sample) = (2, 30, 2687)
# (k, n, sample) = (2, 30, 2688)
# (k, n, sample) = (2, 30, 2689)
# (k, n, sample) = (2, 30, 2690)
# (k, n, sample) = (2, 30, 2691)
# (k, n, sample) = (2, 30, 2692)
# (k, n, sample) = (2, 30, 2693)
# (k, n, sample) = (2, 30, 2694)
# (k, n, sample) = (2, 30, 2695)
# (k, n, sample) = (2, 30, 2696)
# (k, n, sample) = (2, 30, 2697)
# (k, n, sample) = (2, 30, 2698)
# (k, n, sample) = (2, 30, 2699)
# (k, n, sample) = (2, 30, 2700)
# (k, n, sample) = (2, 30, 2701)
# (k, n, sample) = (2, 30, 2702)
# (k, n, sample) = (2, 30, 2703)
# (k, n, sample) = (2, 30, 2704)
# (k, n, sample) = (2, 30, 2705)
# (k, n, sample) = (2, 30, 2706)
# (k, n, sample) = (2, 30, 2707)
# (k, n, sample) = (2, 30, 2708)
# (k, n, sample) = (2, 30, 2709)
# (k, n, sample) = (2, 30, 2710)
# (k, n, sample) = (2, 30, 2711)
# (k, n, sample) = (2, 30, 2712)
# (k, n, sample) = (2, 30, 2713)
# (k, n, sample) = (2, 30, 2714)
# (k, n, sample) = (2, 30, 2715)
# (k, n, sample) = (2, 30, 2716)
# (k, n, sample) = (2, 30, 2717)
# (k, n, sample) = (2, 30, 2718)
# (k, n, sample) = (2, 30, 2719)
# (k, n, sample) = (2, 30, 2720)
# (k, n, sample) = (2, 30, 2721)
# (k, n, sample) = (2, 30, 2722)
# (k, n, sample) = (2, 30, 2723)
# (k, n, sample) = (2, 30, 2724)
# (k, n, sample) = (2, 30, 2725)
# (k, n, sample) = (2, 30, 2726)
# (k, n, sample) = (2, 30, 2727)
# (k, n, sample) = (2, 30, 2728)
# (k, n, sample) = (2, 30, 2729)
# (k, n, sample) = (2, 30, 2730)
# (k, n, sample) = (2, 30, 2731)
# (k, n, sample) = (2, 30, 2732)
# (k, n, sample) = (2, 30, 2733)
# (k, n, sample) = (2, 30, 2734)
# (k, n, sample) = (2, 30, 2735)
# (k, n, sample) = (2, 30, 2736)
# (k, n, sample) = (2, 30, 2737)
# (k, n, sample) = (2, 30, 2738)
# (k, n, sample) = (2, 30, 2739)
# (k, n, sample) = (2, 30, 2740)
# (k, n, sample) = (2, 30, 2741)
# (k, n, sample) = (2, 30, 2742)
# (k, n, sample) = (2, 30, 2743)
# (k, n, sample) = (2, 30, 2744)
# (k, n, sample) = (2, 30, 2745)
# (k, n, sample) = (2, 30, 2746)
# (k, n, sample) = (2, 30, 2747)
# (k, n, sample) = (2, 30, 2748)
# (k, n, sample) = (2, 30, 2749)
# (k, n, sample) = (2, 30, 2750)
# (k, n, sample) = (2, 30, 2751)
# (k, n, sample) = (2, 30, 2752)
# (k, n, sample) = (2, 30, 2753)
# (k, n, sample) = (2, 30, 2754)
# (k, n, sample) = (2, 30, 2755)
# (k, n, sample) = (2, 30, 2756)
# (k, n, sample) = (2, 30, 2757)
# (k, n, sample) = (2, 30, 2758)
# (k, n, sample) = (2, 30, 2759)
# (k, n, sample) = (2, 30, 2760)
# (k, n, sample) = (2, 30, 2761)
# (k, n, sample) = (2, 30, 2762)
# (k, n, sample) = (2, 30, 2763)
# (k, n, sample) = (2, 30, 2764)
# (k, n, sample) = (2, 30, 2765)
# (k, n, sample) = (2, 30, 2766)
# (k, n, sample) = (2, 30, 2767)
# (k, n, sample) = (2, 30, 2768)
# (k, n, sample) = (2, 30, 2769)
# (k, n, sample) = (2, 30, 2770)
# (k, n, sample) = (2, 30, 2771)
# (k, n, sample) = (2, 30, 2772)
# (k, n, sample) = (2, 30, 2773)
# (k, n, sample) = (2, 30, 2774)
# (k, n, sample) = (2, 30, 2775)
# (k, n, sample) = (2, 30, 2776)
# (k, n, sample) = (2, 30, 2777)
# (k, n, sample) = (2, 30, 2778)
# (k, n, sample) = (2, 30, 2779)
# (k, n, sample) = (2, 30, 2780)
# (k, n, sample) = (2, 30, 2781)
# (k, n, sample) = (2, 30, 2782)
# (k, n, sample) = (2, 30, 2783)
# (k, n, sample) = (2, 30, 2784)
# (k, n, sample) = (2, 30, 2785)
# (k, n, sample) = (2, 30, 2786)
# (k, n, sample) = (2, 30, 2787)
# (k, n, sample) = (2, 30, 2788)
# (k, n, sample) = (2, 30, 2789)
# (k, n, sample) = (2, 30, 2790)
# (k, n, sample) = (2, 30, 2791)
# (k, n, sample) = (2, 30, 2792)
# (k, n, sample) = (2, 30, 2793)
# (k, n, sample) = (2, 30, 2794)
# (k, n, sample) = (2, 30, 2795)
# (k, n, sample) = (2, 30, 2796)
# (k, n, sample) = (2, 30, 2797)
# (k, n, sample) = (2, 30, 2798)
# (k, n, sample) = (2, 30, 2799)
# (k, n, sample) = (2, 30, 2800)
# (k, n, sample) = (2, 30, 2801)
# (k, n, sample) = (2, 30, 2802)
# (k, n, sample) = (2, 30, 2803)
# (k, n, sample) = (2, 30, 2804)
# (k, n, sample) = (2, 30, 2805)
# (k, n, sample) = (2, 30, 2806)
# (k, n, sample) = (2, 30, 2807)
# (k, n, sample) = (2, 30, 2808)
# (k, n, sample) = (2, 30, 2809)
# (k, n, sample) = (2, 30, 2810)
# (k, n, sample) = (2, 30, 2811)
# (k, n, sample) = (2, 30, 2812)
# (k, n, sample) = (2, 30, 2813)
# (k, n, sample) = (2, 30, 2814)
# (k, n, sample) = (2, 30, 2815)
# (k, n, sample) = (2, 30, 2816)
# (k, n, sample) = (2, 30, 2817)
# (k, n, sample) = (2, 30, 2818)
# (k, n, sample) = (2, 30, 2819)
# (k, n, sample) = (2, 30, 2820)
# (k, n, sample) = (2, 30, 2821)
# (k, n, sample) = (2, 30, 2822)
# (k, n, sample) = (2, 30, 2823)
# (k, n, sample) = (2, 30, 2824)
# (k, n, sample) = (2, 30, 2825)
# (k, n, sample) = (2, 30, 2826)
# (k, n, sample) = (2, 30, 2827)
# (k, n, sample) = (2, 30, 2828)
# (k, n, sample) = (2, 30, 2829)
# (k, n, sample) = (2, 30, 2830)
# (k, n, sample) = (2, 30, 2831)
# (k, n, sample) = (2, 30, 2832)
# (k, n, sample) = (2, 30, 2833)
# (k, n, sample) = (2, 30, 2834)
# (k, n, sample) = (2, 30, 2835)
# (k, n, sample) = (2, 30, 2836)
# (k, n, sample) = (2, 30, 2837)
# (k, n, sample) = (2, 30, 2838)
# (k, n, sample) = (2, 30, 2839)
# (k, n, sample) = (2, 30, 2840)
# (k, n, sample) = (2, 30, 2841)
# (k, n, sample) = (2, 30, 2842)
# (k, n, sample) = (2, 30, 2843)
# (k, n, sample) = (2, 30, 2844)
# (k, n, sample) = (2, 30, 2845)
# (k, n, sample) = (2, 30, 2846)
# (k, n, sample) = (2, 30, 2847)
# (k, n, sample) = (2, 30, 2848)
# (k, n, sample) = (2, 30, 2849)
# (k, n, sample) = (2, 30, 2850)
# (k, n, sample) = (2, 30, 2851)
# (k, n, sample) = (2, 30, 2852)
# (k, n, sample) = (2, 30, 2853)
# (k, n, sample) = (2, 30, 2854)
# (k, n, sample) = (2, 30, 2855)
# (k, n, sample) = (2, 30, 2856)
# (k, n, sample) = (2, 30, 2857)
# (k, n, sample) = (2, 30, 2858)
# (k, n, sample) = (2, 30, 2859)
# (k, n, sample) = (2, 30, 2860)
# (k, n, sample) = (2, 30, 2861)
# (k, n, sample) = (2, 30, 2862)
# (k, n, sample) = (2, 30, 2863)
# (k, n, sample) = (2, 30, 2864)
# (k, n, sample) = (2, 30, 2865)
# (k, n, sample) = (2, 30, 2866)
# (k, n, sample) = (2, 30, 2867)
# (k, n, sample) = (2, 30, 2868)
# (k, n, sample) = (2, 30, 2869)
# (k, n, sample) = (2, 30, 2870)
# (k, n, sample) = (2, 30, 2871)
# (k, n, sample) = (2, 30, 2872)
# (k, n, sample) = (2, 30, 2873)
# (k, n, sample) = (2, 30, 2874)
# (k, n, sample) = (2, 30, 2875)
# (k, n, sample) = (2, 30, 2876)
# (k, n, sample) = (2, 30, 2877)
# (k, n, sample) = (2, 30, 2878)
# (k, n, sample) = (2, 30, 2879)
# (k, n, sample) = (2, 30, 2880)
# (k, n, sample) = (2, 30, 2881)
# (k, n, sample) = (2, 30, 2882)
# (k, n, sample) = (2, 30, 2883)
# (k, n, sample) = (2, 30, 2884)
# (k, n, sample) = (2, 30, 2885)
# (k, n, sample) = (2, 30, 2886)
# (k, n, sample) = (2, 30, 2887)
# (k, n, sample) = (2, 30, 2888)
# (k, n, sample) = (2, 30, 2889)
# (k, n, sample) = (2, 30, 2890)
# (k, n, sample) = (2, 30, 2891)
# (k, n, sample) = (2, 30, 2892)
# (k, n, sample) = (2, 30, 2893)
# (k, n, sample) = (2, 30, 2894)
# (k, n, sample) = (2, 30, 2895)
# (k, n, sample) = (2, 30, 2896)
# (k, n, sample) = (2, 30, 2897)
# (k, n, sample) = (2, 30, 2898)
# (k, n, sample) = (2, 30, 2899)
# (k, n, sample) = (2, 30, 2900)
# (k, n, sample) = (2, 30, 2901)
# (k, n, sample) = (2, 30, 2902)
# (k, n, sample) = (2, 30, 2903)
# (k, n, sample) = (2, 30, 2904)
# (k, n, sample) = (2, 30, 2905)
# (k, n, sample) = (2, 30, 2906)
# (k, n, sample) = (2, 30, 2907)
# (k, n, sample) = (2, 30, 2908)
# (k, n, sample) = (2, 30, 2909)
# (k, n, sample) = (2, 30, 2910)
# (k, n, sample) = (2, 30, 2911)
# (k, n, sample) = (2, 30, 2912)
# (k, n, sample) = (2, 30, 2913)
# (k, n, sample) = (2, 30, 2914)
# (k, n, sample) = (2, 30, 2915)
# (k, n, sample) = (2, 30, 2916)
# (k, n, sample) = (2, 30, 2917)
# (k, n, sample) = (2, 30, 2918)
# (k, n, sample) = (2, 30, 2919)
# (k, n, sample) = (2, 30, 2920)
# (k, n, sample) = (2, 30, 2921)
# (k, n, sample) = (2, 30, 2922)
# (k, n, sample) = (2, 30, 2923)
# (k, n, sample) = (2, 30, 2924)
# (k, n, sample) = (2, 30, 2925)
# (k, n, sample) = (2, 30, 2926)
# (k, n, sample) = (2, 30, 2927)
# (k, n, sample) = (2, 30, 2928)
# (k, n, sample) = (2, 30, 2929)
# (k, n, sample) = (2, 30, 2930)
# (k, n, sample) = (2, 30, 2931)
# (k, n, sample) = (2, 30, 2932)
# (k, n, sample) = (2, 30, 2933)
# (k, n, sample) = (2, 30, 2934)
# (k, n, sample) = (2, 30, 2935)
# (k, n, sample) = (2, 30, 2936)
# (k, n, sample) = (2, 30, 2937)
# (k, n, sample) = (2, 30, 2938)
# (k, n, sample) = (2, 30, 2939)
# (k, n, sample) = (2, 30, 2940)
# (k, n, sample) = (2, 30, 2941)
# (k, n, sample) = (2, 30, 2942)
# (k, n, sample) = (2, 30, 2943)
# (k, n, sample) = (2, 30, 2944)
# (k, n, sample) = (2, 30, 2945)
# (k, n, sample) = (2, 30, 2946)
# (k, n, sample) = (2, 30, 2947)
# (k, n, sample) = (2, 30, 2948)
# (k, n, sample) = (2, 30, 2949)
# (k, n, sample) = (2, 30, 2950)
# (k, n, sample) = (2, 30, 2951)
# (k, n, sample) = (2, 30, 2952)
# (k, n, sample) = (2, 30, 2953)
# (k, n, sample) = (2, 30, 2954)
# (k, n, sample) = (2, 30, 2955)
# (k, n, sample) = (2, 30, 2956)
# (k, n, sample) = (2, 30, 2957)
# (k, n, sample) = (2, 30, 2958)
# (k, n, sample) = (2, 30, 2959)
# (k, n, sample) = (2, 30, 2960)
# (k, n, sample) = (2, 30, 2961)
# (k, n, sample) = (2, 30, 2962)
